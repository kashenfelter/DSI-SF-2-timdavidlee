# %%
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
import requests
webpath = "https://careers-uber.icims.com/jobs/24996/job?iis=job-V002A-eng&iisn=Indeed&rx_campaign=indeed126&rx_group=101590&rx_job=24996&rx_source=Indeed&rx_medium=cpc&iisc=ppc&mobile=false&width=1092&height=500&bga=true&needsRedirect=false&jan1offset=-480&jun1offset=-420"

#webpath = 'https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population'
response = requests.get(webpath)
HTML = response.text

# %%
print HTML
# Out:
# <!DOCTYPE html><!-- We need front end gurus like you! Email your LinkedIn profile to uber-dot-com-recruiting at uber.com--><html lang="en-US" dir="ltr"><head>
#
# <base href="https://www.uber.com/" />
#
#
#
# ...
