# %%
import scrapy
import pandas as pd
import numpy as np
import time
import requests
import pandas
from scrapy.selector import Selector
from scrapy.http import HtmlResponse

# %%
webpath = "https://www.google.com/about/careers/jobs#t=sq&q=j&li=20&l=false&jlo=en-US&jcoid=7c8c6665-81cf-4e11-8fc9-ec1d6a69120c&jcoid=e43afd0d-d215-45db-a154-5386c9036525&jl=37.3860517%3A-122.0838511%3AMountain+View%2C+CA%2C+USA%3AUS%3AUnited+States%3A9.901223692706639%3ALOCALITY%3A%3A%3A%3ACA%3ASanta+Clara+County%3AMountain+View&jl=37.7749295%3A-122.41941550000001%3ASan+Francisco%2C+CA%2C+USA%3AUS%3AUS%3A7.6750685520230215%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=34.0522342%3A-118.2436849%3ALos+Angeles%2C+CA%2C+USA%3AUS%3AUS%3A34.22569184564956%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=47.6062095%3A-122.3320708%3ASeattle%2C+WA%2C+USA%3AUS%3A%3A9.901225651567486%3ALOCALITY%3A%3A%3A%3A%3A%3A&jld=20&"
response = requests.get(webpath)
HTML = response.text

# %%
import sys
from PyQt4.QtGui import *  
from PyQt4.QtCore import *  
from PyQt4.QtWebKit import *  
from lxml import html 

class Render(QWebPage):  
    def __init__(self, url):  
        self.app = QApplication(sys.argv)  
        QWebPage.__init__(self)  
        self.loadFinished.connect(self._loadFinished)  
        self.mainFrame().load(QUrl(url))  
        self.app.exec_()  

    def _loadFinished(self, result):  
        self.frame = self.mainFrame()  
        self.app.quit()

# %%
url = 'https://www.google.com/about/careers/jobs#t=sq&q=j&li=20&l=false&jlo=en-US&jcoid=7c8c6665-81cf-4e11-8fc9-ec1d6a69120c&jcoid=e43afd0d-d215-45db-a154-5386c9036525&jl=37.3860517%3A-122.0838511%3AMountain+View%2C+CA%2C+USA%3AUS%3AUnited+States%3A9.901223692706639%3ALOCALITY%3A%3A%3A%3ACA%3ASanta+Clara+County%3AMountain+View&jl=37.7749295%3A-122.41941550000001%3ASan+Francisco%2C+CA%2C+USA%3AUS%3AUS%3A7.6750685520230215%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=34.0522342%3A-118.2436849%3ALos+Angeles%2C+CA%2C+USA%3AUS%3AUS%3A34.22569184564956%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=47.6062095%3A-122.3320708%3ASeattle%2C+WA%2C+USA%3AUS%3A%3A9.901225651567486%3ALOCALITY%3A%3A%3A%3A%3A%3A&jld=20&'  
#This does the magic.Loads everything
r = Render(url)  
#result is a QString.
result = r.frame.toHtml()




#Now using correct Xpath we are fetching URL of archives
#archive_links = tree.xpath('//div[@class="campaign"]/a/@href')
#print archive_links

# %%
#QString should be converted to string before processed by lxml
formatted_result = str(result.toAscii())

#Next build lxml tree from formatted_result
tree = html.fromstring(formatted_result)

# %%
print result

# %%
import dryscrape
from bs4 import BeautifulSoup
session = dryscrape.Session()
my_url='https://www.google.com/about/careers/jobs#t=sq&q=j&li=20&l=false&jlo=en-US&jcoid=7c8c6665-81cf-4e11-8fc9-ec1d6a69120c&jcoid=e43afd0d-d215-45db-a154-5386c9036525&jl=37.3860517%3A-122.0838511%3AMountain+View%2C+CA%2C+USA%3AUS%3AUnited+States%3A9.901223692706639%3ALOCALITY%3A%3A%3A%3ACA%3ASanta+Clara+County%3AMountain+View&jl=37.7749295%3A-122.41941550000001%3ASan+Francisco%2C+CA%2C+USA%3AUS%3AUS%3A7.6750685520230215%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=34.0522342%3A-118.2436849%3ALos+Angeles%2C+CA%2C+USA%3AUS%3AUS%3A34.22569184564956%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=47.6062095%3A-122.3320708%3ASeattle%2C+WA%2C+USA%3AUS%3A%3A9.901225651567486%3ALOCALITY%3A%3A%3A%3A%3A%3A&jld=20&'  
session.visit(my_url)
response = session.body()
soup = BeautifulSoup(response)
print soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head itemscope="" itemtype="http://schema.org/WebPageElement"><meta charset="utf-8"/><link href="/about/careers/jobs/css/jobs-careers-desktop.css" rel="stylesheet" type="text/css"/><style nonce="6H7Dg+JRYcysNHWBsl/buErmC3w">@font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 100;
#   src: local('Roboto Thin'), local('Roboto-Thin'), url(//fonts.gstatic.com/s/roboto/v15/Jzo62I39jc0gQRrbndN6nXYhjbSpvc47ee6xR_80Hnw.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 100;
#   src: local('Roboto Thin Italic'), local('Roboto-ThinItalic'), url(//fonts.gstatic.com/s/roboto/v15/12mE4jfMSBTmg-81EiS-YcDdSZkkecOE1hvV7ZHvhyU.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
# ...

# %%
Selector(text=response).xpath("//h2/a[@class='sr-title text']/span[@itemprop='name title']/text()").extract()
# Out:
# [u'Brand Design Lead, Brand Studio',
#  u'Program Manager, Operations',
#  u'Data Architect, Sales Operations',
#  u'Security Technical Account Manager, Google for Work',
#  u'Technical Program Manager, Android Wear',
#  u'Telco Partner Manager, Google for Work',
#  u'Online Sales Nurture Strategist, Google for Work',
#  u'Bay Area Security Systems Project Manager',
#  u'Strategic Partner Development Manager, Chrome OS Lead ...',
#  u'International Insights Program Manager, Localization, Partners ...',
#  u'Account Executive, App Vertical',
#  u'Technical Program Manager, Enterprise Partner Engineering ...',
#  u'Contact Center and Voice Infrastructure Engineer',
#  u'Gaming Backend Engineer (ATAP)',
#  u'Lead Mobile Games Engineer (ATAP)',
#  u'Hardware Strategy Principal',
#  u'Product Support Specialist (Multiple Products), Consumers, Google ...',
#  u'Test Engineer, Access',
#  u'Global Product Lead, Cross-Media Tools',
# ...

# %%
subpath =[x.encode('utf-8') for x in Selector(text=response).xpath("//h2/a[@class='sr-title text']/@href").extract()]
print subpath, len(subpath)
# Out:
# ['#!t=jo&jid=/google/brand-design-lead-brand-studio-345-spear-st-san-francisco-ca-usa-1172680304&', '#!t=jo&jid=/google/program-manager-operations-1600-amphitheatre-pkwy-mountain-view-ca-1530350007&', '#!t=jo&jid=/google/data-architect-sales-operations-1600-amphitheatre-pkwy-mountain-view-ca-1277170005&', '#!t=jo&jid=/google/security-technical-account-manager-1600-amphitheatre-pkwy-mountain-view-ca-1082100026&', '#!t=jo&jid=/google/technical-program-manager-android-wear-1600-amphitheatre-pkwy-mountain-view-ca-1349200007&', '#!t=jo&jid=/google/telco-partner-manager-google-for-work-1600-amphitheatre-pkwy-mountain-view-ca-1002870025&', '#!t=jo&jid=/google/online-sales-nurture-strategist-google-1600-amphitheatre-pkwy-mountain-view-ca-1194110017&', '#!t=jo&jid=/google/bay-area-security-systems-project-1600-amphitheatre-pkwy-mountain-view-ca-1106510465&', '#!t=jo&jid=/google/strategic-partner-development-manager-1600-amphitheatre-pkwy-mountain-view-ca-934140038&', '#!t=jo&jid=/google/inter
# ...

# %%
base_domain = "https://www.google.com/about/careers/jobs"
for b in subpath[0:1]:
    url = base_domain + b
    print url
    session2 = dryscrape.Session()
    session2.visit(url)
    subresponse = session2.body()
    print subresponse
# Out:
# https://www.google.com/about/careers/jobs#!t=jo&jid=/google/brand-design-lead-brand-studio-345-spear-st-san-francisco-ca-usa-1172680304&
# <!DOCTYPE html><html lang="en-US"><head itemscope="" itemtype="http://schema.org/WebPageElement"><meta charset="UTF-8"><link rel="stylesheet" type="text/css" href="/about/careers/jobs/css/jobs-careers-desktop.css"><style nonce="WN7iqsh0VtObVrSJSDcDeJEivX8">@font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 100;
#   src: local('Roboto Thin'), local('Roboto-Thin'), url(//fonts.gstatic.com/s/roboto/v15/Jzo62I39jc0gQRrbndN6nXYhjbSpvc47ee6xR_80Hnw.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 100;
#   src: local('Roboto Thin Italic'), local('Roboto-ThinItalic'), url(//fonts.gstatic.com/s/roboto/v15/12mE4jfMSBTmg-81EiS-YcDdSZkkecOE1hvV7ZHvhyU.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
# ...

# %%
# Out:
# u'<!DOCTYPE html><html lang="en-US"><head itemscope="" itemtype="http://schema.org/WebPageElement"><meta charset="UTF-8" /><link rel="stylesheet" type="text/css" href="/about/careers/jobs/css/jobs-careers-desktop.css"><style nonce="lx6DF7KMTw2gRjKQkzP+hU52dG8">@font-face {\n  font-family: \'Roboto\';\n  font-style: normal;\n  font-weight: 100;\n  src: local(\'Roboto Thin\'), local(\'Roboto-Thin\'), url(//fonts.gstatic.com/s/roboto/v15/Jzo62I39jc0gQRrbndN6nfesZW2xOQ-xsNqO47m55DA.ttf) format(\'truetype\');\n}\n@font-face {\n  font-family: \'Roboto\';\n  font-style: italic;\n  font-weight: 100;\n  src: local(\'Roboto Thin Italic\'), local(\'Roboto-ThinItalic\'), url(//fonts.gstatic.com/s/roboto/v15/12mE4jfMSBTmg-81EiS-YS3USBnSvpkopQaUR-2r7iU.ttf) format(\'truetype\');\n}\n@font-face {\n  font-family: \'Roboto\';\n  font-style: normal;\n  font-weight: 300;\n  src: local(\'Roboto Light\'), local(\'Roboto-Light\'), url(//fonts.gstatic.com/s/roboto/v15/Hgo13k-tfSpn0qi1SFdUfaCWcynf_cDxXwCLxi
# ...

# %%
print Selector(text=subresponse).xpath('//span[@class="location secondary-text"]/text()').extract()

print Selector(text=subresponse).xpath('//span[@class="text"]/text()').extract()
# Out:
# [u'San Francisco, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'San Francisco, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Mountain View, CA, USA', u'Los Angeles, CA, USA', u'Mountain View, CA, USA']
# ...

# %%
print Selector(text=subresponse).xpath('//div[@class="sr-content-text"]').extract()
# Out:
# [u'<div class="sr-content-text"> <div class="sr-content"> <h2 class="sr-title-container subhead2 ON3FLVC-eb-c"> <a class="sr-title text" role="button" itemprop="url" title="Brand Design Lead, Brand Studio" tabindex="400" href="#!t=jo&amp;jid=/google/brand-design-lead-brand-studio-345-spear-st-san-francisco-ca-usa-1172680304&amp;"><span><span class="material-icons-extended ON3FLVC-s-d" role="presentation" aria-hidden="true" style="display: none; ">open_in_new</span></span><span itemprop="name title">Brand Design Lead, Brand Studio</span></a> </h2> <div class="summary"><span class="secondary-text">Google</span><span class="separator secondary-text" aria-hidden="true">\xa0\u2013\xa0</span><span class="location secondary-text" title="San Francisco, CA, USA">San Francisco, CA, USA</span><span class="location secondary-text" style="display: none; " aria-hidden="true"></span></div> </div> <div class="sr-desc"><span class="text secondary-text"></span><span class="text" style="display: none; 
# ...

# %%
"https://www.google.com/about/careers/jobs#t=sq&q=j&li=20&st=20&l=false&jlo=en-US&jl=37.3860517%3A-122.0838511%3AMountain+View%2C+CA%2C+USA%3AUS%3AUnited+States%3A9.901223692706639%3ALOCALITY%3A%3A%3A%3ACA%3ASanta+Clara+County%3AMountain+View&jl=37.7749295%3A-122.41941550000001%3ASan+Francisco%2C+CA%2C+USA%3AUS%3AUS%3A7.6750685520230215%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=34.0522342%3A-118.2436849%3ALos+Angeles%2C+CA%2C+USA%3AUS%3AUS%3A34.22569184564956%3ALOCALITY%3A%3A%3A%3A%3A%3A&jl=47.6062095%3A-122.3320708%3ASeattle%2C+WA%2C+USA%3AUS%3A%3A9.901225651567486%3ALOCALITY%3A%3A%3A%3A%3A%3A&jld=20&jcoid=7c8c6665-81cf-4e11-8fc9-ec1d6a69120c&jcoid=e43afd0d-d215-45db-a154-5386c9036525&"

# %%
print range(20,20*100,20)
# Out:
# [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220, 1240, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480, 1500, 1520, 1540, 1560, 1580, 1600, 1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980]

# %%
url="https://www.google.com/about/careers/jobs#!t=jo&jid=/google/program-manager-operations-1600-amphitheatre-pkwy-mountain-view-ca-1530350007&"


class Render(QWebPage):  
    def __init__(self, url):  
        self.app = QApplication(sys.argv)  
        QWebPage.__init__(self)  
        self.loadFinished.connect(self._loadFinished)  
        self.mainFrame().load(QUrl(url))  
        self.app.exec_()  

    def _loadFinished(self, result):  
        self.frame = self.mainFrame()  
        self.app.quit()
# Out:
# <!DOCTYPE html><html lang="en-US"><head itemscope="" itemtype="http://schema.org/WebPageElement"><meta charset="UTF-8"><link rel="stylesheet" type="text/css" href="/about/careers/jobs/css/jobs-careers-desktop.css"><style nonce="wO4M+/c/whDuiGtlmUkQzHXwTQ0">@font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 100;
#   src: local('Roboto Thin'), local('Roboto-Thin'), url(//fonts.gstatic.com/s/roboto/v15/Jzo62I39jc0gQRrbndN6nXYhjbSpvc47ee6xR_80Hnw.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 100;
#   src: local('Roboto Thin Italic'), local('Roboto-ThinItalic'), url(//fonts.gstatic.com/s/roboto/v15/12mE4jfMSBTmg-81EiS-YcDdSZkkecOE1hvV7ZHvhyU.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 300;
# ...

# %%
import com.gargoylesoftware.htmlunit.WebClient as WebClient
import com.gargoylesoftware.htmlunit.BrowserVersion as BrowserVersion
 


webclient = WebClient(BrowserVersion.FIREFOX_3_6) # creating a new webclient object.
url = "http://www.gartner.com/it/products/mq/mq_ms.jsp"
page = webclient.getPage(url) # getting the url
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-df784b41e787> in <module>()
# ----> 1 import com.gargoylesoftware.htmlunit.WebClient as WebClient
#       2 import com.gargoylesoftware.htmlunit.BrowserVersion as BrowserVersion
#       3
#       4 def main():
#       5
#
# ImportError: No module named com.gargoylesoftware.htmlunit.WebClient
