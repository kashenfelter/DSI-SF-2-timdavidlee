# %%
#=================================== importing the libraries ===================================

import pandas as pd
import numpy as np
import cPickle as pickle
#=================================== NLP Libraries ===================================
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tag import pos_tag
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import PunktSentenceTokenizer

# %%
# =================================================================================================
# Loading the clean'ed dataset
#
# ============================================================================================================

with open('indeed_job_detail_master_16k_df.p','rb') as f:
    master_df = pickle.load(f)

# %%
# =================================================================================================
#pulling out  titles and companies for Glass door
#
#============================================================================================================
listco = [str(x) for x in master_df.company_x.values.tolist()]
with open('listco.txt','wb') as f:
    f.write('\n'.join(listco))
    
titlez = [str(x) for x in master_df.title.values.tolist()]
with open('titlez.txt','wb') as f:
    f.write('\n'.join(titlez))

# %%
# Check the size
print master_df.shape
# Out:
# (14669, 18)

# %%
# ============================================================================================================
# Clean Data sample
#
# ============================================================================================================

master_df.head(2)
# Out:
#                                  company_x  \
# 0                     Advocate Health Care
# 1  University of Washington Medical Center
#
#                                              jobdesc            jobkey  \
# 0  As part of Advocate Health Care, Advocate Chil...  6244f7f3a48616a1
# 1  The University of Washington (UW) is proud to ...  3d6a9f18f530167d
#
#              location                                               snip  \
# 0  Oak Lawn, IL 60453  \nAs part of Advocate Health Care, Advocate Ch...
# 1         Seattle, WA  \nThe University of Washington (UW) is proud t...
#
#                                    title  \
# 0  Clinical Practice Specialist - 4 Hope
# 1                          WEB DEVELOPER
#
#                                                  url      city  \
# 0  http://www.indeed.com/viewjob?jk=6244f7f3a4861...  Oak Lawn
# 1  http://www.indeed.com/viewjob?jk=3d6a9f18f5301...   Seattle
#
#                                  company_y                           date  \
# 0                     Advocate Health Care  Wed, 14 Sep 2016 13:15:06 GMT
# 1  University of Washington Medical Center  Tue, 30 Aug 2016 20:20:18 GMT
#
#            filename formattedLocation formattedLocationFull  \
# 0  CHI_jobdata.json      Oak Lawn, IL    Oak Lawn, IL 60453
# 1  SEA_jobdata.json       Seattle, WA           Seattle, WA
#
#                                 jobtitle   latitude  longitude  \
# 0  Clinical Practice Specialist - 4 Hope  41.719692  -87.74613
# 1                          WEB DEVELOPER  47.604397 -122.32967
#
#                                     source state
# 0                     Advocate Health Care    IL
# 1  University of Washington Medical Center    WA

# %%
# ============================================================================================================
# EDA - look at the first 1000 rows of hte dataset
#
# ============================================================================================================

sample = master_df.head(1000)

# %%
# Set up stop works (words to ignore in the NLP analysis)
# runs a few minutes
from nltk.corpus import stopwords
stop = stopwords.words('english') + ['view','job','save','apply','email','friend', 'recommended', 'days','ago','30']

# running through the initial Count vectorizor of the worlds
cvec = CountVectorizer(stop_words=stop, decode_error='ignore', encoding='utf-8',lowercase=True,ngram_range=(2,4))
cvec.fit(sample['snip'])

#storing in a dataframe
cdf  = pd.DataFrame(cvec.transform(sample['snip']).todense(),
             columns=cvec.get_feature_names())

# %%
cdf.sum().sort_values(ascending=False).head(30)
# Out:
# business analyst              788
# years experience              518
# data analyst                  414
# communication skills          411
# bachelor degree               410
# new york                      376
# analyst jobs                  333
# atlanta ga                    318
# analyst salaries              313
# york ny                       307
# new york ny                   307
# problem solving               304
# computer science              290
# equal opportunity             288
# experience working            284
# big data                      284
# ability work                  270
# san francisco                 269
# project management            254
# skills ability                253
# business intelligence         245
# opportunity employer          233
# machine learning              228
# chicago il                    225
# indeed easily                 224
# seattle wa                    223
# san francisco ca              220
# francisco ca                  220
# data analytics                218
# equal opportunity employer    214
# dtype: int64

# %%
# compare using TFIDF
tvec = TfidfVectorizer(stop_words=stop, decode_error='ignore', encoding='utf-8',lowercase=True, ngram_range=(2,5))
tvec.fit(sample['snip'])

tdf  = pd.DataFrame(tvec.transform(sample['snip']).todense(),
             columns=tvec.get_feature_names())

# %%
tdf.sum().sort_values(ascending=False).head(30)
# Out:
# business analyst         7.664473
# new york                 4.839338
# data analyst             4.716925
# atlanta ga               4.434705
# york ny                  4.253951
# new york ny              4.253951
# years experience         3.832588
# san francisco            3.630345
# seattle wa               3.274637
# san francisco ca         3.245878
# francisco ca             3.245878
# big data                 3.180232
# chicago il               3.033002
# communication skills     3.000277
# business intelligence    2.974508
# machine learning         2.881722
# bachelor degree          2.881003
# software engineer        2.730499
# experience working       2.709834
# minneapolis mn           2.706005
# analyst jobs             2.637627
# computer science         2.612515
# analyst salaries         2.557712
# data engineer            2.527648
# problem solving          2.468091
# ability work             2.459743
# los angeles              2.451944
# washington dc            2.348517
# please review            2.327676
# project management       2.321255
# dtype: float64

# %%
# testing the parts of speech analysis
tok = WordPunctTokenizer()
pos_tag(tok.tokenize("today is a great day to learn nlp"))
# Out:
# [('today', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('day', 'NN'),
#  ('to', 'TO'),
#  ('learn', 'VB'),
#  ('nlp', 'NN')]

# %%
# look at a single sample and see if we can
# 1.) break by sentence
# 2.) break by parts of speech into phrases
# 3.) then into words
print sample['snip'][8]
# Out:
# Solution ArchitectFairfax, VAAbout ICF's Information Insights (I2) GroupICF's Information Insights (I2) team is comprised of experienced professionals with the skills required to unlock the power of governed data discovery. Our staff provides deep technical and business support for data acquisition, data analysis/data science, and interactive data visualizations.Job Description: We're looking for a Solution Architect who wants to be responsible for defining technology solutions. You'll integrate different domain applications and data in ways that enhance our clients' current environments and helps pushes them forward to next generation capabilities. This will include helping them build and support data science environments in AWS as well as applying big data analytics in a coordinated, cohesive manner to help clients solve business use cases they could not previously address.What you'll be doing: * Develop long-term partnerships with customers and vendors and contribute to the development of their strategic business plans by understanding the future direction of their organization, the industry, and the customer's business.* Develop working relationships with staff to facilitate the adoption of best practices, including standards, methodology and metrics in preparing architecture deliverables and be comfortable creating rapidly delivered prototypes that speed client approvals.* Work closely with the stakeholder groups to translate business use cases to specific solution architecture design, including assisting with planning the implementation timelines and then looping back to address subsequent questions and confirming implementation guidelines are followed.Basic Qualifications: * Bachelor's degree in a technical field: Computer Science, Engineering or related discipline.* 10 years' experience developing solutions across a range of industry, client and technologies.* Significant experience defining technical architecture, infrastructure design, system requirements, and technical analysis/design as well as implementing data management systems, including experience with Big Data systems (e.g., Hadoop, MongoDB), data warehouses, and reporting/analytic systems.* Significant knowledge of / experience with contemporary integration technologies and frameworks (e.g., ETL, MDM, EAI, Web Service).* Ability to obtain a security clearancePreferred Skills/Experience: * Experience with driving Agile Software Delivery Life Cycle in a business environment.* Experience with Vendor Management, software evaluation and selection.* Experience with large-scale or Massively Parallel Processing database implementations as well as large-scale structured and unstructured datasets.* Experience with applied data science, including modeling and quantitative analysis using standard statistical software such as SASProfessional Skills: * Excellent listening, written, and oral communication skills paired with an excellent sense of humor* Ability to exercise independent judgment while effectively prioritizing and executing tasks while under pressure* Team player with the ability to work in a fast-paced environmentAbout ICF InternationalICF International (NASDAQ: ICFI) provides professional services and technology solutions that deliver beneficial impact in areas critical to the world's future.
#
# ICF is fluent in the language of change, whether driven by markets, technology, or policy. Since 1969, we have combined a passion for our work with deep industry expertise to tackle our clients' most important challenges. We partner with clients around the globe—advising, executing, innovating—to help them define and achieve success. Our more than 5,000 employees serve government and commercial clients from more than 70 offices worldwide.
#
# ICF's website is http://www.icfi.com/.ICF offers an excellent benefits package, an award winning talent development program, and fosters a highly skilled, energized and empowered workforce.ICF is an equal opportunity employer that values diversity at all levels. (EEO/AA – Minorities/Females/Veterans/Individuals with Disabilities)
#
# ICF International, Inc - 28 days ago  - save job
#
#
#
#
#
#
#
#
#
# »
#
#                         View or apply to job
#
#
# Recommended Jobs
#
# Solutions Architect
#
# Princeton Information Ltd -
# 		 Herndon, VA
# 7 days ago
#
#  Easily apply
# Solutions Architect
#
# The Midtown Group -
# 		 Washington, DC
# 14 days ago
# Solutions Architect
#
# Elemental Solutions, LLC -
# 		 Bethesda, MD
# Indeed -
# 		 26 days ago
#
#  Easily apply
# Solutions Architect
#
# International Software systems -
# 		 Maryland City, MD
# Indeed -
# 		 12 days ago
#
#  Easily apply
# Solutions Architect
#
# The McKenna Principals Inc -
# 		 Washington, DC
# 30+ days ago
#
#
#
#
#
#
#
#
# Email this job to a friend
#
#
#
#
#
#
#
# Solution Architect jobs in Fairfax, VA
#
#
# Jobs at ICF International in Fairfax, VA
#
#
# Solution Architect salaries in Fairfax, VA

# %%
#try to cleanup the text -- any type of spaces / etc.
print 
decoded_str = sample['jobdesc'][8].decode("windows-1252")
encoded_str = decoded_str.encode("utf8").replace("â€™","'")

print encoded_str
# Out:
# Solution ArchitectFairfax, VAAbout ICF's Information Insights (I2) GroupICF's Information Insights (I2) team is comprised of experienced professionals with the skills required to unlock the power of governed data discovery. Our staff provides deep technical and business support for data acquisition, data analysis/data science, and interactive data visualizations.Job Description: We're looking for a Solution Architect who wants to be responsible for defining technology solutions. You'll integrate different domain applications and data in ways that enhance our clients' current environments and helps pushes them forward to next generation capabilities. This will include helping them build and support data science environments in AWS as well as applying big data analytics in a coordinated, cohesive manner to help clients solve business use cases they could not previously address.What you'll be doing: * Develop long-term partnerships with customers and vendors and contribute to the development of their strategic business plans by understanding the future direction of their organization, the industry, and the customer's business.* Develop working relationships with staff to facilitate the adoption of best practices, including standards, methodology and metrics in preparing architecture deliverables and be comfortable creating rapidly delivered prototypes that speed client approvals.* Work closely with the stakeholder groups to translate business use cases to specific solution architecture design, including assisting with planning the implementation timelines and then looping back to address subsequent questions and confirming implementation guidelines are followed.Basic Qualifications: * Bachelor's degree in a technical field: Computer Science, Engineering or related discipline.* 10 years' experience developing solutions across a range of industry, client and technologies.* Significant experience defining technical architecture, infrastructure design, system requirements, and technical analysis/design as well as implementing data management systems, including experience with Big Data systems (e.g., Hadoop, MongoDB), data warehouses, and reporting/analytic systems.* Significant knowledge of / experience with contemporary integration technologies and frameworks (e.g., ETL, MDM, EAI, Web Service).* Ability to obtain a security clearancePreferred Skills/Experience: * Experience with driving Agile Software Delivery Life Cycle in a business environment.* Experience with Vendor Management, software evaluation and selection.* Experience with large-scale or Massively Parallel Processing database implementations as well as large-scale structured and unstructured datasets.* Experience with applied data science, including modeling and quantitative analysis using standard statistical software such as SASProfessional Skills: * Excellent listening, written, and oral communication skills paired with an excellent sense of humor* Ability to exercise independent judgment while effectively prioritizing and executing tasks while under pressure* Team player with the ability to work in a fast-paced environmentAbout ICF InternationalICF International (NASDAQ: ICFI) provides professional services and technology solutions that deliver beneficial impact in areas critical to the world's future.
# ICF is fluent in the language of change, whether driven by markets, technology, or policy. Since 1969, we have combined a passion for our work with deep industry expertise to tackle our clients' most important challenges. We partner with clients around the globeâ€”advising, executing, innovatingâ€”to help them define and achieve success. Our more than 5,000 employees serve government and commercial clients from more than 70 offices worldwide.
# ICF's website is http://www.icfi.com/.ICF offers an excellent benefits package, an award winning talent development program, and fosters a highly skilled, energized and empowered workforce.ICF is an equal opportunity employer that values diversity at all levels. (EEO/AA â€“ Minorities/Females/Veterans/Individuals with Disabilities)

# %%
#view the paragraph as sentences
sent_detector = PunktSentenceTokenizer()
sent_detector.sentences_from_text(encoded_str)
# Out:
# ["Solution ArchitectFairfax, VAAbout ICF's Information Insights (I2) GroupICF's Information Insights (I2) team is comprised of experienced professionals with the skills required to unlock the power of governed data discovery.",
#  "Our staff provides deep technical and business support for data acquisition, data analysis/data science, and interactive data visualizations.Job Description: We're looking for a Solution Architect who wants to be responsible for defining technology solutions.",
#  "You'll integrate different domain applications and data in ways that enhance our clients' current environments and helps pushes them forward to next generation capabilities.",
#  "This will include helping them build and support data science environments in AWS as well as applying big data analytics in a coordinated, cohesive manner to help clients solve business use cases they could not previously address.What you'll be doing: * Develop long-term partnerships with customers and vendors and contribute to the development of their strategic business plans by understanding the future direction of their organization, the industry, and the customer's business.",
#  '* Develop working relationships with staff to facilitate the adoption of best practices, including standards, methodology and metrics in preparing architecture deliverables and be comfortable creating rapidly delivered prototypes that speed client approvals.',
#  "* Work closely with the stakeholder groups to translate business use cases to specific solution architecture design, including assisting with planning the implementation timelines and then looping back to address subsequent questions and confirming implementation guidelines are followed.Basic Qualifications: * Bachelor's degree in a technical field: Computer Science, Engineering or related discipline.",
#  "* 10 years' experience developing solutions across a range of industry, client and technologies.",
#  '* Significant experience defining technical architecture, infrastructure design, system requirements, and technical analysis/design as well as implementing data management systems, including experience with Big Data systems (e.g., Hadoop, MongoDB), data warehouses, and reporting/analytic systems.',
#  '* Significant knowledge of / experience with contemporary integration technologies and frameworks (e.g., ETL, MDM, EAI, Web Service).',
#  '* Ability to obtain a security clearancePreferred Skills/Experience: * Experience with driving Agile Software Delivery Life Cycle in a business environment.',
#  '* Experience with Vendor Management, software evaluation and selection.',
#  '* Experience with large-scale or Massively Parallel Processing database implementations as well as large-scale structured and unstructured datasets.',
#  "* Experience with applied data science, including modeling and quantitative analysis using standard statistical software such as SASProfessional Skills: * Excellent listening, written, and oral communication skills paired with an excellent sense of humor* Ability to exercise independent judgment while effectively prioritizing and executing tasks while under pressure* Team player with the ability to work in a fast-paced environmentAbout ICF InternationalICF International (NASDAQ: ICFI) provides professional services and technology solutions that deliver beneficial impact in areas critical to the world's future.",
#  'ICF is fluent in the language of change, whether driven by markets, technology, or policy.',
#  "Since 1969, we have combined a passion for our work with deep industry expertise to tackle our clients' most important challenges.",
#  'We partner with clients around the globe\xc3\xa2\xe2\x82\xac\xe2\x80\x9dadvising, executing, innovating\xc3\xa2\xe2\x82\xac\xe2\x80\x9dto help them define and achieve success.',
#  'Our more than 5,000 employees serve government and commercial clients from more than 70 offices worldwide.',
#  "ICF's website is http://www.icfi.com/.ICF offers an excellent benefits package, an award winning talent development program, and fosters a highly skilled, energized and empowered workforce.ICF is an equal opportunity employer that values diversity at all levels.",
#  '(EEO/AA \xc3\xa2\xe2\x82\xac\xe2\x80\x9c Minorities/Females/Veterans/Individuals with Disabilities)']

# %%
# look at one of the sentences 
tok_sample = pos_tag(tok.tokenize(sample['jobdesc'][8]))
tok_sample
# Out:
# [('Solution', 'NNP'),
#  ('ArchitectFairfax', 'NNP'),
#  (',', ','),
#  ('VAAbout', 'NNP'),
#  ('ICF', 'NNP'),
#  ("'", 'POS'),
#  ('s', 'JJ'),
#  ('Information', 'NNP'),
#  ('Insights', 'NNP'),
#  ('(', '('),
#  ('I2', 'NNP'),
#  (')', ')'),
#  ('GroupICF', 'NNP'),
#  ("'", 'POS'),
#  ('s', 'JJ'),
#  ('Information', 'NNP'),
#  ('Insights', 'NNP'),
#  ('(', '('),
#  ('I2', 'NNP'),
#  (')', ')'),
#  ('team', 'NN'),
#  ('is', 'VBZ'),
#  ('comprised', 'VBN'),
#  ('of', 'IN'),
#  ('experienced', 'JJ'),
#  ('professionals', 'NNS'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('skills', 'NNS'),
#  ('required', 'VBN'),
#  ('to', 'TO'),
#  ('unlock', 'VB'),
#  ('the', 'DT'),
#  ('power', 'NN'),
#  ('of', 'IN'),
#  ('governed', 'VBN'),
#  ('data', 'NNS'),
#  ('discovery', 'NN'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('staff', 'NN'),
#  ('provides', 'VBZ'),
#  ('deep', 'JJ'),
#  ('technical', 'JJ'),
#  ('and', 'CC'),
#  ('business', 'NN'),
#  ('support', 'NN'),
#  ('for', 'IN'),
#  ('data', 'NNS'),
#  ('acquisition', 'NN'),
#  (',', ','),
#  ('data', 'NNS'),
#  ('analysis', 'NN'),
#  ('/', 'NNP'),
#  ('data', 'NN'),
#  ('science', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('interactive', 'JJ'),
#  ('data', 'NNS'),
#  ('visualizations', 'NNS'),
#  ('.', '.'),
#  ('Job', 'NNP'),
#  ('Description', 'NNP'),
#  (':', ':'),
#  ('We', 'PRP'),
#  ("'", "''"),
#  ('re', 'VBP'),
#  ('looking', 'VBG'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('Solution', 'NNP'),
#  ('Architect', 'NNP'),
#  ('who', 'WP'),
#  ('wants', 'VBZ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('responsible', 'JJ'),
#  ('for', 'IN'),
#  ('defining', 'VBG'),
#  ('technology', 'NN'),
#  ('solutions', 'NNS'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ("'", "''"),
#  ('ll', 'JJ'),
#  ('integrate', 'NN'),
#  ('different', 'JJ'),
#  ('domain', 'NN'),
#  ('applications', 'NNS'),
#  ('and', 'CC'),
#  ('data', 'NNS'),
#  ('in', 'IN'),
#  ('ways', 'NNS'),
#  ('that', 'WDT'),
#  ('enhance', 'VBP'),
#  ('our', 'PRP$'),
#  ('clients', 'NNS'),
#  ("'", 'POS'),
#  ('current', 'JJ'),
#  ('environments', 'NNS'),
#  ('and', 'CC'),
#  ('helps', 'VBZ'),
#  ('pushes', 'VB'),
#  ('them', 'PRP'),
#  ('forward', 'RB'),
#  ('to', 'TO'),
#  ('next', 'JJ'),
#  ('generation', 'NN'),
#  ('capabilities', 'NNS'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('will', 'MD'),
#  ('include', 'VB'),
#  ('helping', 'VBG'),
#  ('them', 'PRP'),
#  ('build', 'VB'),
#  ('and', 'CC'),
#  ('support', 'VB'),
#  ('data', 'NNS'),
#  ('science', 'NN'),
#  ('environments', 'NNS'),
#  ('in', 'IN'),
#  ('AWS', 'NNP'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('applying', 'VBG'),
#  ('big', 'JJ'),
#  ('data', 'NNS'),
#  ('analytics', 'NNS'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('coordinated', 'JJ'),
#  (',', ','),
#  ('cohesive', 'JJ'),
#  ('manner', 'NN'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('clients', 'NNS'),
#  ('solve', 'VB'),
#  ('business', 'NN'),
#  ('use', 'NN'),
#  ('cases', 'NNS'),
#  ('they', 'PRP'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('previously', 'RB'),
#  ('address', 'RB'),
#  ('.', '.'),
#  ('What', 'WP'),
#  ('you', 'PRP'),
#  ("'", "''"),
#  ('ll', 'RB'),
#  ('be', 'VB'),
#  ('doing', 'VBG'),
#  (':', ':'),
#  ('*', 'NNS'),
#  ('Develop', 'NNP'),
#  ('long', 'RB'),
#  ('-', ':'),
#  ('term', 'NN'),
#  ('partnerships', 'NNS'),
#  ('with', 'IN'),
#  ('customers', 'NNS'),
#  ('and', 'CC'),
#  ('vendors', 'NNS'),
#  ('and', 'CC'),
#  ('contribute', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('development', 'NN'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('strategic', 'JJ'),
#  ('business', 'NN'),
#  ('plans', 'NNS'),
#  ('by', 'IN'),
#  ('understanding', 'VBG'),
#  ('the', 'DT'),
#  ('future', 'JJ'),
#  ('direction', 'NN'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('organization', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('industry', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('customer', 'NN'),
#  ("'", 'POS'),
#  ('s', 'NN'),
#  ('business', 'NN'),
#  ('.*', 'NNP'),
#  ('Develop', 'NNP'),
#  ('working', 'VBG'),
#  ('relationships', 'NNS'),
#  ('with', 'IN'),
#  ('staff', 'NN'),
#  ('to', 'TO'),
#  ('facilitate', 'VB'),
#  ('the', 'DT'),
#  ('adoption', 'NN'),
#  ('of', 'IN'),
#  ('best', 'JJS'),
#  ('practices', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('standards', 'NNS'),
#  (',', ','),
#  ('methodology', 'NN'),
#  ('and', 'CC'),
#  ('metrics', 'NNS'),
#  ('in', 'IN'),
#  ('preparing', 'VBG'),
#  ('architecture', 'NN'),
#  ('deliverables', 'NNS'),
#  ('and', 'CC'),
#  ('be', 'VB'),
#  ('comfortable', 'JJ'),
#  ('creating', 'VBG'),
#  ('rapidly', 'RB'),
#  ('delivered', 'VBN'),
#  ('prototypes', 'NNS'),
#  ('that', 'IN'),
#  ('speed', 'NN'),
#  ('client', 'NN'),
#  ('approvals', 'NNS'),
#  ('.*', 'VBP'),
#  ('Work', 'NNP'),
#  ('closely', 'RB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('stakeholder', 'NN'),
#  ('groups', 'NNS'),
#  ('to', 'TO'),
#  ('translate', 'VB'),
#  ('business', 'NN'),
#  ('use', 'NN'),
#  ('cases', 'NNS'),
#  ('to', 'TO'),
#  ('specific', 'JJ'),
#  ('solution', 'NN'),
#  ('architecture', 'NN'),
#  ('design', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('assisting', 'VBG'),
#  ('with', 'IN'),
#  ('planning', 'VBG'),
#  ('the', 'DT'),
#  ('implementation', 'NN'),
#  ('timelines', 'NNS'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('looping', 'VBG'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('address', 'VB'),
#  ('subsequent', 'JJ'),
#  ('questions', 'NNS'),
#  ('and', 'CC'),
#  ('confirming', 'VBG'),
#  ('implementation', 'NN'),
#  ('guidelines', 'NNS'),
#  ('are', 'VBP'),
#  ('followed', 'VBN'),
#  ('.', '.'),
#  ('Basic', 'JJ'),
#  ('Qualifications', 'NNS'),
#  (':', ':'),
#  ('*', 'NN'),
#  ('Bachelor', 'NNP'),
#  ("'", 'POS'),
#  ('s', 'NN'),
#  ('degree', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('technical', 'JJ'),
#  ('field', 'NN'),
#  (':', ':'),
#  ('Computer', 'NNP'),
#  ('Science', 'NNP'),
#  (',', ','),
#  ('Engineering', 'NNP'),
#  ('or', 'CC'),
#  ('related', 'VBN'),
#  ('discipline', 'NN'),
#  ('.*', 'VBZ'),
#  ('10', 'CD'),
#  ('years', 'NNS'),
#  ("'", 'POS'),
#  ('experience', 'NN'),
#  ('developing', 'VBG'),
#  ('solutions', 'NNS'),
#  ('across', 'IN'),
#  ('a', 'DT'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('industry', 'NN'),
#  (',', ','),
#  ('client', 'NN'),
#  ('and', 'CC'),
#  ('technologies', 'NNS'),
#  ('.*', 'NNP'),
#  ('Significant', 'NNP'),
#  ('experience', 'NN'),
#  ('defining', 'VBG'),
#  ('technical', 'JJ'),
#  ('architecture', 'NN'),
#  (',', ','),
#  ('infrastructure', 'NN'),
#  ('design', 'NN'),
#  (',', ','),
#  ('system', 'NN'),
#  ('requirements', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('technical', 'JJ'),
#  ('analysis', 'NN'),
#  ('/', 'NNP'),
#  ('design', 'NN'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('implementing', 'VBG'),
#  ('data', 'JJ'),
#  ('management', 'NN'),
#  ('systems', 'NNS'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('experience', 'NN'),
#  ('with', 'IN'),
#  ('Big', 'NNP'),
#  ('Data', 'NNP'),
#  ('systems', 'NNS'),
#  ('(', '('),
#  ('e', 'NN'),
#  ('.', '.'),
#  ('g', 'NN'),
#  ('.,', 'JJ'),
#  ('Hadoop', 'NNP'),
#  (',', ','),
#  ('MongoDB', 'NNP'),
#  ('),', 'NNP'),
#  ('data', 'NN'),
#  ('warehouses', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('reporting', 'VBG'),
#  ('/', 'NNP'),
#  ('analytic', 'JJ'),
#  ('systems', 'NNS'),
#  ('.*', 'JJ'),
#  ('Significant', 'NNP'),
#  ('knowledge', 'NN'),
#  ('of', 'IN'),
#  ('/', 'JJ'),
#  ('experience', 'NN'),
#  ('with', 'IN'),
#  ('contemporary', 'JJ'),
#  ('integration', 'NN'),
#  ('technologies', 'NNS'),
#  ('and', 'CC'),
#  ('frameworks', 'NNS'),
#  ('(', '('),
#  ('e', 'NN'),
#  ('.', '.'),
#  ('g', 'NN'),
#  ('.,', 'JJ'),
#  ('ETL', 'NNP'),
#  (',', ','),
#  ('MDM', 'NNP'),
#  (',', ','),
#  ('EAI', 'NNP'),
#  (',', ','),
#  ('Web', 'NNP'),
#  ('Service', 'NNP'),
#  (').*', 'NNP'),
#  ('Ability', 'NNP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('a', 'DT'),
#  ('security', 'NN'),
#  ('clearancePreferred', 'VBN'),
#  ('Skills', 'NNP'),
#  ('/', 'JJ'),
#  ('Experience', 'NN'),
#  (':', ':'),
#  ('*', 'JJ'),
#  ('Experience', 'NN'),
#  ('with', 'IN'),
#  ('driving', 'VBG'),
#  ('Agile', 'NNP'),
#  ('Software', 'NNP'),
#  ('Delivery', 'NNP'),
#  ('Life', 'NNP'),
#  ('Cycle', 'NNP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('business', 'NN'),
#  ('environment', 'NN'),
#  ('.*', 'NNP'),
#  ('Experience', 'NNP'),
#  ('with', 'IN'),
#  ('Vendor', 'NNP'),
#  ('Management', 'NNP'),
#  (',', ','),
#  ('software', 'NN'),
#  ('evaluation', 'NN'),
#  ('and', 'CC'),
#  ('selection', 'NN'),
#  ('.*', 'NNS'),
#  ('Experience', 'NN'),
#  ('with', 'IN'),
#  ('large', 'JJ'),
#  ('-', ':'),
#  ('scale', 'NN'),
#  ('or', 'CC'),
#  ('Massively', 'RB'),
#  ('Parallel', 'JJ'),
#  ('Processing', 'NNP'),
#  ('database', 'NN'),
#  ('implementations', 'NNS'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('large', 'JJ'),
#  ('-', ':'),
#  ('scale', 'NN'),
#  ('structured', 'JJ'),
#  ('and', 'CC'),
#  ('unstructured', 'JJ'),
#  ('datasets', 'NNS'),
#  ('.*', 'JJ'),
#  ('Experience', 'NNP'),
#  ('with', 'IN'),
#  ('applied', 'VBN'),
#  ('data', 'NNS'),
#  ('science', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('modeling', 'NN'),
#  ('and', 'CC'),
#  ('quantitative', 'JJ'),
#  ('analysis', 'NN'),
#  ('using', 'VBG'),
#  ('standard', 'JJ'),
#  ('statistical', 'JJ'),
#  ('software', 'NN'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('SASProfessional', 'JJ'),
#  ('Skills', 'NNS'),
#  (':', ':'),
#  ('*', 'JJ'),
#  ('Excellent', 'NNP'),
#  ('listening', 'NN'),
#  (',', ','),
#  ('written', 'VBN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('oral', 'JJ'),
#  ('communication', 'NN'),
#  ('skills', 'NNS'),
#  ('paired', 'VBN'),
#  ('with', 'IN'),
#  ('an', 'DT'),
#  ('excellent', 'JJ'),
#  ('sense', 'NN'),
#  ('of', 'IN'),
#  ('humor', 'NN'),
#  ('*', 'NNP'),
#  ('Ability', 'NNP'),
#  ('to', 'TO'),
#  ('exercise', 'VB'),
#  ('independent', 'JJ'),
#  ('judgment', 'NN'),
#  ('while', 'IN'),
#  ('effectively', 'RB'),
#  ('prioritizing', 'VBG'),
#  ('and', 'CC'),
#  ('executing', 'VBG'),
#  ('tasks', 'NNS'),
#  ('while', 'IN'),
#  ('under', 'IN'),
#  ('pressure', 'NN'),
#  ('*', 'NNP'),
#  ('Team', 'NNP'),
#  ('player', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('ability', 'NN'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('fast', 'JJ'),
#  ('-', ':'),
#  ('paced', 'VBN'),
#  ('environmentAbout', 'IN'),
#  ('ICF', 'NNP'),
#  ('InternationalICF', 'NNP'),
#  ('International', 'NNP'),
#  ('(', '('),
#  ('NASDAQ', 'NNP'),
#  (':', ':'),
#  ('ICFI', 'NNP'),
#  (')', ')'),
#  ('provides', 'VBZ'),
#  ('professional', 'JJ'),
#  ('services', 'NNS'),
#  ('and', 'CC'),
#  ('technology', 'NN'),
#  ('solutions', 'NNS'),
#  ('that', 'WDT'),
#  ('deliver', 'VBP'),
#  ('beneficial', 'JJ'),
#  ('impact', 'NN'),
#  ('in', 'IN'),
#  ('areas', 'NNS'),
#  ('critical', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ("'", 'POS'),
#  ('s', 'JJ'),
#  ('future', 'NN'),
#  ('.', '.'),
#  ('ICF', 'NNP'),
#  ('is', 'VBZ'),
#  ('fluent', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('language', 'NN'),
#  ('of', 'IN'),
#  ('change', 'NN'),
#  (',', ','),
#  ('whether', 'IN'),
#  ('driven', 'VBN'),
#  ('by', 'IN'),
#  ('markets', 'NNS'),
#  (',', ','),
#  ('technology', 'NN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('policy', 'NN'),
#  ('.', '.'),
#  ('Since', 'IN'),
#  ('1969', 'CD'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('combined', 'VBN'),
#  ('a', 'DT'),
#  ('passion', 'NN'),
#  ('for', 'IN'),
#  ('our', 'PRP$'),
#  ('work', 'NN'),
#  ('with', 'IN'),
#  ('deep', 'JJ'),
#  ('industry', 'NN'),
#  ('expertise', 'NN'),
#  ('to', 'TO'),
#  ('tackle', 'VB'),
#  ('our', 'PRP$'),
#  ('clients', 'NNS'),
#  ("'", 'POS'),
#  ('most', 'RBS'),
#  ('important', 'JJ'),
#  ('challenges', 'NNS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('partner', 'NN'),
#  ('with', 'IN'),
#  ('clients', 'NNS'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('globe\xe2', 'NN'),
#  ('\x80\x94', 'NNP'),
#  ('advising', 'NN'),
#  (',', ','),
#  ('executing', 'VBG'),
#  (',', ','),
#  ('innovating\xe2', 'JJ'),
#  ('\x80\x94', 'NN'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('them', 'PRP'),
#  ('define', 'VB'),
#  ('and', 'CC'),
#  ('achieve', 'VB'),
#  ('success', 'NN'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('5', 'CD'),
#  (',', ','),
#  ('000', 'CD'),
#  ('employees', 'NNS'),
#  ('serve', 'VBP'),
#  ('government', 'NN'),
#  ('and', 'CC'),
#  ('commercial', 'JJ'),
#  ('clients', 'NNS'),
#  ('from', 'IN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('70', 'CD'),
#  ('offices', 'NNS'),
#  ('worldwide', 'RB'),
#  ('.', '.'),
#  ('ICF', 'NNP'),
#  ("'", 'POS'),
#  ('s', 'NN'),
#  ('website', 'NN'),
#  ('is', 'VBZ'),
#  ('http', 'JJ'),
#  ('://', 'NNP'),
#  ('www', 'NN'),
#  ('.', '.'),
#  ('icfi', 'NN'),
#  ('.', '.'),
#  ('com', 'NN'),
#  ('/.', 'NN'),
#  ('ICF', 'NNP'),
#  ('offers', 'VBZ'),
#  ('an', 'DT'),
#  ('excellent', 'JJ'),
#  ('benefits', 'NNS'),
#  ('package', 'NN'),
#  (',', ','),
#  ('an', 'DT'),
#  ('award', 'NN'),
#  ('winning', 'VBG'),
#  ('talent', 'NN'),
#  ('development', 'NN'),
#  ('program', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('fosters', 'NNS'),
#  ('a', 'DT'),
#  ('highly', 'RB'),
#  ('skilled', 'VBN'),
#  (',', ','),
#  ('energized', 'VBN'),
#  ('and', 'CC'),
#  ('empowered', 'VBN'),
#  ('workforce', 'NN'),
#  ('.', '.'),
#  ('ICF', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('equal', 'JJ'),
#  ('opportunity', 'NN'),
#  ('employer', 'NN'),
#  ('that', 'WDT'),
#  ('values', 'VBZ'),
#  ('diversity', 'NN'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  ('levels', 'NNS'),
#  ('.', '.'),
#  ('(', '('),
#  ('EEO', 'NNP'),
#  ('/', 'NNP'),
#  ('AA', 'NNP'),
#  ('\xe2', 'NNP'),
#  ('\x80\x93', 'NNP'),
#  ('Minorities', 'NNP'),
#  ('/', 'NNP'),
#  ('Females', 'NNP'),
#  ('/', 'NNP'),
#  ('Veterans', 'NNP'),
#  ('/', 'JJ'),
#  ('Individuals', 'NNS'),
#  ('with', 'IN'),
#  ('Disabilities', 'NNS'),
#  (')', ')')]

# %%
# All nouns
print [x for x in tok_sample if x[1]=='NNP']
# Out:
# [('Solution', 'NNP'), ('ArchitectFairfax', 'NNP'), ('VAAbout', 'NNP'), ('ICF', 'NNP'), ('Information', 'NNP'), ('Insights', 'NNP'), ('I2', 'NNP'), ('GroupICF', 'NNP'), ('Information', 'NNP'), ('Insights', 'NNP'), ('I2', 'NNP'), ('/', 'NNP'), ('Job', 'NNP'), ('Description', 'NNP'), ('Solution', 'NNP'), ('Architect', 'NNP'), ('AWS', 'NNP'), ('Develop', 'NNP'), ('.*', 'NNP'), ('Develop', 'NNP'), ('Work', 'NNP'), ('Bachelor', 'NNP'), ('Computer', 'NNP'), ('Science', 'NNP'), ('Engineering', 'NNP'), ('.*', 'NNP'), ('Significant', 'NNP'), ('/', 'NNP'), ('Big', 'NNP'), ('Data', 'NNP'), ('Hadoop', 'NNP'), ('MongoDB', 'NNP'), ('),', 'NNP'), ('/', 'NNP'), ('Significant', 'NNP'), ('ETL', 'NNP'), ('MDM', 'NNP'), ('EAI', 'NNP'), ('Web', 'NNP'), ('Service', 'NNP'), (').*', 'NNP'), ('Ability', 'NNP'), ('Skills', 'NNP'), ('Agile', 'NNP'), ('Software', 'NNP'), ('Delivery', 'NNP'), ('Life', 'NNP'), ('Cycle', 'NNP'), ('.*', 'NNP'), ('Experience', 'NNP'), ('Vendor', 'NNP'), ('Management', 'NNP'), ('Processing', 'NNP'), ('Experience', 'NNP'), ('Excellent', 'NNP'), ('*', 'NNP'), ('Ability', 'NNP'), ('*', 'NNP'), ('Team', 'NNP'), ('ICF', 'NNP'), ('InternationalICF', 'NNP'), ('International', 'NNP'), ('NASDAQ', 'NNP'), ('ICFI', 'NNP'), ('ICF', 'NNP'), ('\x80\x94', 'NNP'), ('ICF', 'NNP'), ('://', 'NNP'), ('ICF', 'NNP'), ('ICF', 'NNP'), ('EEO', 'NNP'), ('/', 'NNP'), ('AA', 'NNP'), ('\xe2', 'NNP'), ('\x80\x93', 'NNP'), ('Minorities', 'NNP'), ('/', 'NNP'), ('Females', 'NNP'), ('/', 'NNP'), ('Veterans', 'NNP')]

# %%
# All verbs
print [x for x in tok_sample if 'V' in x[1]]
# Out:
# [('is', 'VBZ'), ('comprised', 'VBN'), ('required', 'VBN'), ('unlock', 'VB'), ('governed', 'VBN'), ('provides', 'VBZ'), ('re', 'VBP'), ('looking', 'VBG'), ('wants', 'VBZ'), ('be', 'VB'), ('defining', 'VBG'), ('enhance', 'VBP'), ('helps', 'VBZ'), ('pushes', 'VB'), ('include', 'VB'), ('helping', 'VBG'), ('build', 'VB'), ('support', 'VB'), ('applying', 'VBG'), ('help', 'VB'), ('solve', 'VB'), ('be', 'VB'), ('doing', 'VBG'), ('understanding', 'VBG'), ('working', 'VBG'), ('facilitate', 'VB'), ('including', 'VBG'), ('preparing', 'VBG'), ('be', 'VB'), ('creating', 'VBG'), ('delivered', 'VBN'), ('.*', 'VBP'), ('translate', 'VB'), ('including', 'VBG'), ('assisting', 'VBG'), ('planning', 'VBG'), ('looping', 'VBG'), ('address', 'VB'), ('confirming', 'VBG'), ('are', 'VBP'), ('followed', 'VBN'), ('related', 'VBN'), ('.*', 'VBZ'), ('developing', 'VBG'), ('defining', 'VBG'), ('implementing', 'VBG'), ('including', 'VBG'), ('reporting', 'VBG'), ('obtain', 'VB'), ('clearancePreferred', 'VBN'), ('driving', 'VBG'), ('applied', 'VBN'), ('including', 'VBG'), ('using', 'VBG'), ('written', 'VBN'), ('paired', 'VBN'), ('exercise', 'VB'), ('prioritizing', 'VBG'), ('executing', 'VBG'), ('work', 'VB'), ('paced', 'VBN'), ('provides', 'VBZ'), ('deliver', 'VBP'), ('is', 'VBZ'), ('driven', 'VBN'), ('have', 'VBP'), ('combined', 'VBN'), ('tackle', 'VB'), ('executing', 'VBG'), ('help', 'VB'), ('define', 'VB'), ('achieve', 'VB'), ('serve', 'VBP'), ('is', 'VBZ'), ('offers', 'VBZ'), ('winning', 'VBG'), ('skilled', 'VBN'), ('energized', 'VBN'), ('empowered', 'VBN'), ('is', 'VBZ'), ('values', 'VBZ')]
