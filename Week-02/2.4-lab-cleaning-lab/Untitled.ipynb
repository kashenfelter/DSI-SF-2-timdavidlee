# %%
import pandas as pd
import numpy as np

rock_path = '/Users/tlee010/desktop/dsi-sf-2-timdavidlee/datasets/rock.csv'
rock_data = pd.read_csv(rock_path)
rock_data.drop('First?',axis = 1, inplace=True)

# %%
def clean_year(input_data):
    a = input_data['Release Year']
    input_data['cleaned_year'] = a
    return input_data

rock_data.apply(clean_year, axis=1)
# Out:
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
print rock_data.iloc[2224,]

rock_data.iloc[2000:2004,[1,2]]
# Out:
# Song Clean                Sharp Dressed Man
# ARTIST CLEAN                         ZZ Top
# Release Year                           1983
# COMBINED        Sharp Dressed Man by ZZ Top
# Year?                                     1
# PlayCount                               120
# F*G                                     120
# Name: 2224, dtype: object
#            ARTIST CLEAN Release Year
# 2000  The White Stripes         2003
# 2001            The Who         1973
# 2002            The Who          NaN
# 2003            The Who         1982
