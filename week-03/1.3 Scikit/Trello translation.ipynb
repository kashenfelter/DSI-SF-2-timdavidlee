# %%
import json
from pprint import pprint
trello_file = '/Users/tlee010/desktop/dsi-sf-2-timdavidlee/trello.json'
with open(trello_file) as json_data:
    d = json.load(json_data)
    #print(d)
print json.dumps(d, sort_keys=True, indent=4, separators=(',', ': '))
# Out:
# {
#     "actions": [
#         {
#             "data": {
#                 "board": {
#                     "id": "579657f86ea26ff7fa809d2a",
#                     "name": "DSI-SF-2-SCHEDULE",
#                     "shortLink": "zdFG2LdB"
#                 },
#                 "idMemberAdded": "57982feebd1e989b3acb2606",
#                 "idMemberInviter": "56f3042205d1fd7db63fcbcd",
#                 "memberType": "normal",
#                 "method": "invitationSecret"
#             },
#             "date": "2016-07-27T03:53:03.978Z",
#             "id": "5798301f2ff0da0163b9881c",
#             "idMemberCreator": "57982feebd1e989b3acb2606",
#             "member": {
#                 "avatarHash": null,
#                 "fullName": "Daniel Moreno",
#                 "id": "57982feebd1e989b3acb2606",
#                 "initials": "DM",
#                 "username": "danielmoreno64"
#             },
#             "memberCreator": {
#                 "avatarHash": null,
# ...

# %%
d['cards'][0]
# Out:
# {u'attachments': [],
#  u'badges': {u'attachments': 0,
#   u'checkItems': 0,
#   u'checkItemsChecked': 0,
#   u'comments': 0,
#   u'description': False,
#   u'due': u'2016-07-25T19:00:00.000Z',
#   u'fogbugz': u'',
#   u'subscribed': False,
#   u'viewingMemberVoted': False,
#   u'votes': 0},
#  u'checkItemStates': None,
#  u'closed': False,
#  u'dateLastActivity': u'2016-07-25T18:18:32.330Z',
#  u'desc': u'',
#  u'descData': None,
#  u'due': u'2016-07-25T19:00:00.000Z',
#  u'email': u'timlee67+2mlyzc3agr5ncnku1nq+2mlyvcv2if9l1iqaf5t+02awb4u3e1@boards.trello.com',
#  u'id': u'579657f86ea26ff7fa809d41',
#  u'idAttachmentCover': None,
#  u'idBoard': u'579657f86ea26ff7fa809d2a',
#  u'idChecklists': [],
#  u'idLabels': [u'579657f86ea26ff7fa809d38'],
#  u'idList': u'579657f86ea26ff7fa809d2b',
#  u'idMembers': [],
#  u'idMembersVoted': [],
#  u'idShort': 1,
#  u'labels': [{u'color': u'black',
#    u'id': u'579657f86ea26ff7fa809d38',
#    u'idBoard': u'579657f86ea26ff7fa809d2a',
# ...

# %%
lister =  [str(x['name']) for x in d['cards']]
for x in lister:
    print x
# Out:
# 1.1 Command Line
# 1.2 Intro to Git
# 1.3 Data Types
# 1.4 Lists & Dictionaries
# 2.1 Control Flows
# 2.2 Python Functions Lab
# 2.3 Iteration
# 2.4 Python Movies Lab
# 3.1 Outcomes: Intro
# 3.2 List Comprehensions
# 3.3 Numpy and Distributions
# 3.4 [Lab]
# 4.1 Math Primer
# 4.2 Numpy Lab
# 4.3 Data Vizualization Pt. 1
# 4.4 [Lab]
# Project 1 Due
# 5.1 Week 1 Review
# 5.2 Week 1 Review
# 5.3 Data Visualization Pt. 2
# 5.4 [Lab]
# 1.1 Intro to Study Design
# 1.2 Basic Statistics
# 1.3 Pandas DataFrames
# 1.4 Numpy & Pandas Lab
# 2.1 Pandas Indexing
# 2.2 Pandas Computation Lab
# 2.3 Intro to Data Cleaning
# 2.4 Data Cleaning Lab
# 3.1 Outcomes: Job Search Workshop
# 3.2 Missing Data Lab
# 3.3 Pandas Pivot Tables
# 3.4 Pivot Tables Lab
# 4.1 Pandas Grouping
# 4.2 Split-Apply-Combine Lab
# 4.3 Pandas Joins
# 4.4 Joins Lab
# Project 2 Due
# 5.1 Week 2 Review pt. 1
# 5.2 Week 2 Review pt. 2
# 5.3 Pandas Plotting
# 5.4 Plotting Lab
# 1.1 Intro to Regression Modeling
# ...
