# %%
infile = open('/users/tlee010/desktop/github_repos/GetOldTweets-python/output_got.csv', 'r') 
f = infile.read()

# %%
rows = f.split('\n')
for x in rows:
    print x.split(';')
# Out:
# ['username', 'date', 'retweets', 'favorites', 'text', 'geo', 'mentions', 'hashtags', 'id', 'permalink']
# ['SkillsMalaysia', '2016-08-20 06:01', '0', '0', '"n Life, we should not build walls around ourselves. #asc2016 #jomasc #kekk pic.twitter.com/nP3UCFYVJ7"', '', '', '#asc2016 #jomasc #kekk', '"766983413735755776"', 'https://twitter.com/SkillsMalaysia/status/766983413735755776']
# ['b4theabstract', '2016-08-19 09:14', '1', '0', '"Do you have a story to tell at #ASC2016 ? Send us your idea for our live criminology storytelling event! http:// bit.ly/2aErC9J"', '', '', '#ASC2016', '"766669670707499008"', 'https://twitter.com/b4theabstract/status/766669670707499008']
# ...
