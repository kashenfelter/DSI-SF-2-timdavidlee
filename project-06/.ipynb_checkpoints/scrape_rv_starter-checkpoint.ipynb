# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 6:  Web Scraping
# ### Finding Underpriced RVs on Craigslist
#
# ![](https://snag.gy/WrdUMx.jpg)

# %% [markdown]
# In this project we will be practicing our web scraping skills.  You can use Scrapy or Python requests in order to complete this project.  It may be helpful to write some prototype code in this notebook to test your assumptions, then move it into a Python file that can be run from the command line.
#
# > In order to run code from the command line, instead of the notebook, you just need to save your code to a file (with a .py extension), and run it using the Python interpreter:<br><br>
# > `python my_file.py`
#
# You will be building a process to scrape a single category of search results on Craigslist, that can easily be applied to other categories by changing the search terms.  The main goal is to be able to target and scrape a single page given a set of parameters.
#
# **If you use Scrapy, provide your code in a folder.**

# %% [markdown]
# ## Import your libraries for scrapy / requests / pandas / numpy / etc
# Setup whichever libraries you need. Review past material for reference.

# %%
# PREPARE REQUIRED LIBRARIES
import scrapy
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1.  Scrape for the largest US cities (non-exhaustive list)
# Search, research, and scrape Wikipedia for a list of the largest US cities.  There are a few sources but find one that is in a nice table.  We don't want all cities, just signifficant cities.  Examine your source.  Look for what can be differentiable.
#
# - Use requests
# - Build XPath query(ies)
# - Extract to a list
# - Clean your list

# %%
# SCRAPE WIKIPEDIA FOR LARGEST US CITIES (NON-EXHAUSTIVE LIST)

from scrapy.selector import Selector
from scrapy.http import HtmlResponse

webpath = 'https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population'
response = requests.get(webpath)
HTML = response.text

# %%
print HTML
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of United States cities by population - Wikipedia, the free encyclopedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_United_States_cities_by_population","wgTitle":"List of United States cities by population","wgCurRevisionId":735363804,"wgRevisionId":735363804,"wgArticleId":1649321,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from August 2014","Lists of coordinates","Geographic coordinate lists","Articles with Geo","Featured lists","Lists of cities in the United States by population","United States demography-related lists","Demographics by city in the United States","Lists of cities by population"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_United_States_cities_by_population","wgRelevantArticleId":1649321,"wgRequestId":"V8PrRwpAMFEAALi2z3IAAAAA","wgIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgFlaggedRevsParams":{"tags":{"status":{"levels":1,"quality":2,"pristine":3}}},"wgStableRevisionId":null,"wgWikibaseItemId":"Q131079","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user.cssprefs":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.nojs":"ready","ext.tmh.thumbnail.styles":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["mediawiki.page.startup","mediawiki.legacy.wikibits","ext.centralauth.centralautologin","mmv.head","ext.visualEditor.desktopArticleTarget.init","ext.uls.interface","ext.quicksurveys.init","mw.MediaWikiPlayer.loader","mw.PopUpMediaTransform","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.gadget.DRN-wizard%2CReferenceTooltips%2Ccharinsert%2Cextra-toolbar-buttons%2Cfeatured-articles-links%2CrefToolbar%2Cswitcher%2Cteahouse%2Cwatchlist-notice%7Cext.tmh.thumbnail.styles%7Cext.uls.nojs%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.28.0-wmf.16"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/List_of_United_States_cities_by_population"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-List_of_United_States_cities_by_population rootpage-List_of_United_States_cities_by_population skin-vector action-view feature-page-action-bar-v2">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# <div id="mw-indicator-featured-star" class="mw-indicator"><a href="/wiki/Wikipedia:Featured_lists" title="This is a featured list. Click here for more information."><img alt="This is a featured list. Click here for more information." src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png" width="20" height="19" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/30px-Cscr-featured.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/40px-Cscr-featured.svg.png 2x" data-file-width="462" data-file-height="438" /></a></div>
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">List of United States cities by population</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div role="note" class="hatnote">"List of largest cities in the United States" redirects here. For a list of largest cities by area, see <a href="/wiki/List_of_United_States_cities_by_area" title="List of United States cities by area">List of United States cities by area</a>.</div>
# <table class="collapsible collapsed noprint infobox" id="GeoGroup" style="width: 23em; font-size: 88%; line-height: 1.5em">
# <tr>
# <th style="text-align:left;"><a class="external text" href="//tools.wmflabs.org/osm4wiki/cgi-bin/wiki/wiki-osm.pl?project=en&amp;article=List_of_United_States_cities_by_population">Map all coordinates using OSM</a><br />
# <a class="external text" href="//tools.wmflabs.org/wp-world/googlmaps-proxy.php?page=https:%2F%2Ftools.wmflabs.org%2Fkmlexport%3Farticle%3DList_of_United_States_cities_by_population&amp;output=classic">Map all coordinates using Google</a><br />
# <a class="external text" href="//tools.wmflabs.org/kmlexport?article=List_of_United_States_cities_by_population&amp;redir=bing">Map up to 200 coordinates using Bing</a></th>
# </tr>
# <tr>
# <td><a class="external text" href="//tools.wmflabs.org/kmlexport?article=List_of_United_States_cities_by_population">Export all coordinates</a> as <a href="/wiki/Keyhole_Markup_Language" title="Keyhole Markup Language">KML</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://maps.bing.com/GeoCommunity.asjx?action=retrieverss&amp;mkt=en&amp;mapurl=http%3A%2F%2Ftools.wmflabs.org%2Fkmlexport%3Farticle%3DList_of_United_States_cities_by_population">Export all coordinates</a> as <a href="/wiki/GeoRSS" title="GeoRSS">GeoRSS</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://tripgang.com/kml2gpx/http%3A%2F%2Ftools.wmflabs.org%2Fkmlexport%3Farticle%3DList_of_United_States_cities_by_population?gpx=1">Export all coordinates</a> as <a href="/wiki/GPS_eXchange_Format" class="mw-redirect" title="GPS eXchange Format">GPX</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://maps.google.com/maps?q=http%3A%2F%2Fmicroform.at%2Fgeo%2Fhttp%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_United_States_cities_by_population">Map all microformatted coordinates</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://microform.at/?type=hcard-rdf&amp;url=http://en.wikipedia.org/wiki/List_of_United_States_cities_by_population">Place data as RDF</a></td>
# </tr>
# </table>
# <table class="vertical-navbox nowraplinks navbox" style="float:right;clear:right;width:22.0em;margin:0 0 1.0em 1.0em;background:#f9f9f9;border:1px solid #aaa;padding:0.2em;border-spacing:0.4em 0;text-align:center;line-height:1.4em;font-size:88%">
# <tr>
# <th style="padding:0.2em 0.4em 0.2em;font-size:145%;line-height:1.2em">Population tables<br />
# of U.S. cities</th>
# </tr>
# <tr>
# <td style="padding:0.2em 0 0.4em"><a href="/wiki/File:Pano_Manhattan2007_amk.jpg" class="image"><img alt="&quot;New York City skyline&quot;" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pano_Manhattan2007_amk.jpg/250px-Pano_Manhattan2007_amk.jpg" width="250" height="72" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pano_Manhattan2007_amk.jpg/375px-Pano_Manhattan2007_amk.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pano_Manhattan2007_amk.jpg/500px-Pano_Manhattan2007_amk.jpg 2x" data-file-width="2764" data-file-height="800" /></a></td>
# </tr>
# <tr>
# <th style="padding:0.1em"><strong class="selflink">Cities</strong></th>
# </tr>
# <tr>
# <td style="padding:0 0.1em 0.4em">
# <p><span style="font-size:110%;"><strong class="selflink">Population</strong></span></p>
# <div class="hlist">
# <ul>
# <li><a href="/wiki/List_of_United_States_cities_by_area" title="List of United States cities by area">Area</a></li>
# <li><a href="/wiki/List_of_United_States_cities_by_population_density" title="List of United States cities by population density">Density</a></li>
# <li><a href="/wiki/Lists_of_United_States_cities_with_large_ethnic_identity_populations" class="mw-redirect" title="Lists of United States cities with large ethnic identity populations">Ethnic identity</a></li>
# <li><a href="/wiki/List_of_United_States_cities_by_foreign-born_population" title="List of United States cities by foreign-born population">Foreign-born</a></li>
# <li><a href="/wiki/Highest-income_metropolitan_statistical_areas_in_the_United_States" title="Highest-income metropolitan statistical areas in the United States">Income</a></li>
# <li><a href="/wiki/List_of_United_States_cities_by_Spanish-speaking_population" title="List of United States cities by Spanish-speaking population">Spanish speakers</a></li>
# <li><a href="/wiki/Largest_cities_in_the_United_States_by_population_by_decade" title="Largest cities in the United States by population by decade">By decade</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/List_of_United_States_urban_areas" title="List of United States urban areas">Urban areas</a></th>
# </tr>
# <tr>
# <td style="padding:0 0.1em 0.4em"><a href="/wiki/Cities_and_metropolitan_areas_of_the_United_States" title="Cities and metropolitan areas of the United States">Populous cities and metropolitan areas</a></td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/List_of_metropolitan_areas_of_the_United_States" title="List of metropolitan areas of the United States">Metropolitan areas</a></th>
# </tr>
# <tr>
# <td style="padding:0 0.1em 0.4em">
# <div class="plainlist">
# <ul>
# <li><a href="/wiki/List_of_primary_statistical_areas_of_the_United_States" title="List of primary statistical areas of the United States">574 Primary Statistical Areas</a></li>
# <li><a href="/wiki/List_of_Combined_Statistical_Areas" class="mw-redirect" title="List of Combined Statistical Areas">169 Combined Statistical Areas</a></li>
# <li><a href="/wiki/List_of_Core_Based_Statistical_Areas" title="List of Core Based Statistical Areas">929 Core Based Statistical Areas</a></li>
# <li><a href="/wiki/List_of_Metropolitan_Statistical_Areas" title="List of Metropolitan Statistical Areas">389 Metropolitan Statistical Areas</a></li>
# <li><a href="/wiki/List_of_Micropolitan_Statistical_Areas" class="mw-redirect" title="List of Micropolitan Statistical Areas">540 Micropolitan Statistical Areas</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/Megaregions_of_the_United_States" title="Megaregions of the United States">Megaregions</a></th>
# </tr>
# <tr>
# <td class="navbox-abovebelow" style="padding:0.3em 0.4em 0.3em;font-weight:bold;line-height:1.3em;font-weight:normal;">
# <div class="plainlist">
# <ul>
# <li><b>See also</b></li>
# <li><a href="/wiki/List_of_North_American_metropolitan_areas_by_population" title="List of North American metropolitan areas by population">North American metro areas</a></li>
# <li><a href="/wiki/List_of_cities_proper_by_population" title="List of cities proper by population">World cities</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <td style="text-align:right;font-size:115%">
# <div class="plainlinks hlist navbar mini">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:U.S._city_population_tables" title="Template:U.S. city population tables"><abbr title="View this template">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:U.S._city_population_tables" title="Template talk:U.S. city population tables"><abbr title="Discuss this template">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:U.S._city_population_tables&amp;action=edit"><abbr title="Edit this template">e</abbr></a></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# <p>The following is a list of the most populous <a href="/wiki/Municipal_corporation" title="Municipal corporation">incorporated places</a> of the <a href="/wiki/United_States" title="United States">United States</a>. As defined by the <a href="/wiki/United_States_Census_Bureau" title="United States Census Bureau">United States Census Bureau</a>, an "<a href="/wiki/Incorporated_place" class="mw-redirect" title="Incorporated place">incorporated place</a>" includes a variety of designations, including <a href="/wiki/City" title="City">city</a>, <a href="/wiki/Town" title="Town">town</a>, <a href="/wiki/Village" title="Village">village</a>, <a href="/wiki/Borough" title="Borough">borough</a>, and <a href="/wiki/Municipality" title="Municipality">municipality</a>.<sup id="cite_ref-NewEngland_1-0" class="reference"><a href="#cite_note-NewEngland-1">[1]</a></sup> A few exceptional <a href="/wiki/Census-designated_place" title="Census-designated place">Census Designated Places</a> (CDPs) are also included in the Census Bureau's listing of incorporated places.<sup id="cite_ref-HonoluluHI_2-0" class="reference"><a href="#cite_note-HonoluluHI-2">[2]</a></sup> <a href="/wiki/Consolidated_city%E2%80%93county" class="mw-redirect" title="Consolidated city–county">Consolidated city-counties</a> represent a distinct type of government that includes the entire population of a county, or county equivalent. Some consolidated city-counties, however, include multiple incorporated places. This list presents only that portion (or "balance") of such consolidated city-counties that are not a part of another incorporated place.</p>
# <p>This list refers only to the population of individual municipalities within their <a href="/wiki/City_limits" title="City limits">defined limits</a>, which does not include other municipalities or unincorporated <a href="/wiki/Suburb" title="Suburb">suburban</a> areas within <a href="/wiki/Urban_agglomeration" title="Urban agglomeration">urban agglomerations</a>. A different ranking is evident when considering <a href="/wiki/List_of_metropolitan_areas_of_the_United_States" title="List of metropolitan areas of the United States">U.S. metropolitan area populations</a>.</p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#United_States"><span class="tocnumber">1</span> <span class="toctext">United States</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Distribution"><span class="tocnumber">1.1</span> <span class="toctext">Distribution</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Gallery"><span class="tocnumber">1.2</span> <span class="toctext">Gallery</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-4"><a href="#Puerto_Rico"><span class="tocnumber">2</span> <span class="toctext">Puerto Rico</span></a></li>
# <li class="toclevel-1 tocsection-5"><a href="#Census-designated_places"><span class="tocnumber">3</span> <span class="toctext">Census-designated places</span></a></li>
# <li class="toclevel-1 tocsection-6"><a href="#Cities_formerly_over_100.2C000_people"><span class="tocnumber">4</span> <span class="toctext">Cities formerly over 100,000 people</span></a></li>
# <li class="toclevel-1 tocsection-7"><a href="#See_also"><span class="tocnumber">5</span> <span class="toctext">See also</span></a></li>
# <li class="toclevel-1 tocsection-8"><a href="#References"><span class="tocnumber">6</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-9"><a href="#External_links"><span class="tocnumber">7</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <p></p>
# <div style="clear:both;"></div>
# <h2><span class="mw-headline" id="United_States">United States</span></h2>
# <table class="collapsible collapsed noprint infobox" id="GeoGroup" style="width: 23em; font-size: 88%; line-height: 1.5em">
# <tr>
# <th style="text-align:left;"><a class="external text" href="//tools.wmflabs.org/osm4wiki/cgi-bin/wiki/wiki-osm.pl?project=en&amp;article=List_of_United_States_cities_by_population&amp;section=United+States">Map this section's coordinates using OSM</a><br />
# <a class="external text" href="//tools.wmflabs.org/wp-world/googlmaps-proxy.php?page=https:%2F%2Ftools.wmflabs.org%2Fkmlexport%3Farticle%3DList_of_United_States_cities_by_population%26section%3DUnited_States&amp;output=classic">Map this section's coordinates using Google</a><br />
# <a class="external text" href="//tools.wmflabs.org/kmlexport?article=List_of_United_States_cities_by_population&amp;section=United+States&amp;redir=bing">Map up to 200 of this section's coordinates using Bing</a></th>
# </tr>
# <tr>
# <td><a class="external text" href="//tools.wmflabs.org/kmlexport?article=List_of_United_States_cities_by_population&amp;section=United+States">Export this section's coordinates</a> as <a href="/wiki/Keyhole_Markup_Language" title="Keyhole Markup Language">KML</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://maps.bing.com/GeoCommunity.asjx?action=retrieverss&amp;mkt=en&amp;mapurl=http%3A%2F%2Ftools.wmflabs.org%2Fkmlexport%3Farticle%3DList_of_United_States_cities_by_population%26section%3DUnited%2BStates">Export this section's coordinates</a> as <a href="/wiki/GeoRSS" title="GeoRSS">GeoRSS</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://tripgang.com/kml2gpx/http%3A%2F%2Ftools.wmflabs.org%2Fkmlexport%3Farticle%3DList_of_United_States_cities_by_population%26section%3DUnited%2BStates?gpx=1">Export this section's coordinates</a> as <a href="/wiki/GPS_eXchange_Format" class="mw-redirect" title="GPS eXchange Format">GPX</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://maps.google.com/maps?q=http%3A%2F%2Fmicroform.at%2Fgeo%2Fhttp%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_United_States_cities_by_population">Map all microformatted coordinates</a></td>
# </tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="http://microform.at/?type=hcard-rdf&amp;url=http://en.wikipedia.org/wiki/List_of_United_States_cities_by_population">Place data as RDF</a></td>
# </tr>
# </table>
# <div style="float:right;border: 1px solid silver; margin:0 0 0.5em 1em;">
# <div role="img" style="width: 400px; font-size: 85%; line-height: 1; text-align: center; background-color: #ffffff; position: relative;"><a href="/wiki/File:United_States_Administrative_Divisions_Cities.svg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d0/United_States_Administrative_Divisions_Cities.svg/400px-United_States_Administrative_Divisions_Cities.svg.png" width="400" height="247" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d0/United_States_Administrative_Divisions_Cities.svg/600px-United_States_Administrative_Divisions_Cities.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d0/United_States_Administrative_Divisions_Cities.svg/800px-United_States_Administrative_Divisions_Cities.svg.png 2x" data-file-width="959" data-file-height="593" /></a>
# <div style="position:absolute; font-size:118%; left:22px; top:240px">The ten most populous <a href="/wiki/Municipal_corporation" title="Municipal corporation">cities</a> of the <a href="/wiki/United_States" title="United States">United States</a></div>
# <div style="position:absolute; left:283.6px; top:71.2px"><a href="/wiki/New_York_City" title="New York City"><b>1. New York</b></a></div>
# <div style="position:absolute; left:36.8px; top:133.6px"><a href="/wiki/Los_Angeles" title="Los Angeles"><b>2. Los Angeles</b></a></div>
# <div style="position:absolute; left:196px; top:79.2px"><a href="/wiki/Chicago" title="Chicago"><b>3. Chicago</b></a></div>
# <div style="position:absolute; left:211.2px; top:193.2px"><a href="/wiki/Houston" title="Houston"><b>4. Houston</b></a></div>
# <div style="position:absolute; left:260px; top:83.6px"><a href="/wiki/Philadelphia" title="Philadelphia"><b>5. Philadelphia</b></a></div>
# <div style="position:absolute; left:87.2px; top:144.8px"><a href="/wiki/Phoenix,_Arizona" title="Phoenix, Arizona"><b>6. Phoenix</b></a></div>
# <div style="position:absolute; left:101.2px; top:190.4px"><a href="/wiki/San_Antonio" title="San Antonio"><b>7. San Antonio</b></a></div>
# <div style="position:absolute; left:36.8px; top:157.2px"><a href="/wiki/San_Diego" title="San Diego"><b>8. San Diego</b></a></div>
# <div style="position:absolute; left:197.6px; top:171.6px"><a href="/wiki/Dallas" title="Dallas"><b>9. Dallas</b></a></div>
# <div style="position:absolute; left:17.2px; top:95.6px"><a href="/wiki/San_Jose,_California" title="San Jose, California"><b>10. San Jose</b></a></div>
# </div>
# <br /></div>
# <p>The following table lists the 304 <a href="/wiki/Municipal_corporation" title="Municipal corporation">incorporated places</a> in the United States with a population of at least 100,000 on July 1, 2015, as estimated by the <a href="/wiki/United_States_Census_Bureau" title="United States Census Bureau">United States Census Bureau</a>. A city is displayed in <b>bold</b> if it is a state or federal capital, and in <i>italics</i> if it is the most populous city in the state. Five states—<a href="/wiki/Delaware" title="Delaware">Delaware</a>, <a href="/wiki/Maine" title="Maine">Maine</a>, <a href="/wiki/Vermont" title="Vermont">Vermont</a>, <a href="/wiki/West_Virginia" title="West Virginia">West Virginia</a> and <a href="/wiki/Wyoming" title="Wyoming">Wyoming</a>—do not have cities with populations of 100,000 or more. The table below contains the following information:</p>
# <ol>
# <li>The city rank by population as of July 1, 2015, as estimated by the United States Census Bureau<sup id="cite_ref-PopEstCities_3-0" class="reference"><a href="#cite_note-PopEstCities-3">[3]</a></sup></li>
# <li>The city name<sup id="cite_ref-PopEstCities_3-1" class="reference"><a href="#cite_note-PopEstCities-3">[3]</a></sup></li>
# <li>The name of the state in which the city lies<sup id="cite_ref-PopEstCities_3-2" class="reference"><a href="#cite_note-PopEstCities-3">[3]</a></sup></li>
# <li>The city population as of July 1, 2015, as estimated by the United States Census Bureau<sup id="cite_ref-PopEstCities_3-3" class="reference"><a href="#cite_note-PopEstCities-3">[3]</a></sup></li>
# <li>The city population as of April 1, 2010, as enumerated by the <a href="/wiki/2010_United_States_Census" title="2010 United States Census">2010 United States Census</a><sup id="cite_ref-PopEstCities_3-4" class="reference"><a href="#cite_note-PopEstCities-3">[3]</a></sup></li>
# <li>The city percent population change from April 1, 2010, to July 1, 2015</li>
# <li>The city land area as of January 1, 2014<sup id="cite_ref-USCBGazetteer_4-0" class="reference"><a href="#cite_note-USCBGazetteer-4">[4]</a></sup></li>
# <li>The city population density as of July 1, 2015 (residents per unit of land area)<sup id="cite_ref-USCBGazetteer_4-1" class="reference"><a href="#cite_note-USCBGazetteer-4">[4]</a></sup></li>
# <li>The city latitude and longitude coordinates</li>
# </ol>
# <div style="clear:both;"></div>
# <p><span id="Table"></span></p>
# <table class="wikitable sortable" style="text-align:center">
# <tr>
# <th>2015 rank</th>
# <th>City</th>
# <th>State<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">[5]</a></sup></th>
# <th>2015 estimate</th>
# <th>2010 Census</th>
# <th>Change</th>
# <th>2014 land area</th>
# <th>2010 population density</th>
# <th>Location</th>
# </tr>
# <tr>
# <td>1</td>
# <td align="left"><i><a href="/wiki/New_York_City" title="New York City">New York</a></i><sup id="cite_ref-NewYorkNY_6-0" class="reference"><a href="#cite_note-NewYorkNY-6">[6]</a></sup></td>
# <td align="left"><a href="/wiki/New_York" title="New York">New York</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">8,550,405</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">8,175,133</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000459040849855290♠</span><font style="color:green">+4.59%</font></td>
# <td><span style="display:none" class="sortkey">7002302600000000000♠</span>302.6&#160;sq&#160;mi<br />
# 783.8&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7004270120000000000♠</span>27,012&#160;per&#160;sq&#160;mi<br />
# 10,430&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=40.6643_N_73.9385_W_&amp;title=1+New+York+City"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">40°39′51″N</span> <span class="longitude">73°56′19″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">40.6643°N 73.9385°W</span><span style="display:none">﻿ / <span class="geo">40.6643; -73.9385</span></span><span style="display:none">﻿ (<span class="fn org">1 New York City</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>2</td>
# <td align="left"><i><a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a></i></td>
# <td align="left"><a href="/wiki/California" title="California">California</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,971,883</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,792,621</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000472659936228800♠</span><font style="color:green">+4.73%</font></td>
# <td><span style="display:none" class="sortkey">7002468700000000000♠</span>468.7&#160;sq&#160;mi<br />
# 1,213.9&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003809200000000000♠</span>8,092&#160;per&#160;sq&#160;mi<br />
# 3,124&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=34.0194_N_118.4108_W_&amp;title=2+Los+Angeles"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">34°01′10″N</span> <span class="longitude">118°24′39″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">34.0194°N 118.4108°W</span><span style="display:none">﻿ / <span class="geo">34.0194; -118.4108</span></span><span style="display:none">﻿ (<span class="fn org">2 Los Angeles</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>3</td>
# <td align="left"><i><a href="/wiki/Chicago" title="Chicago">Chicago</a></i></td>
# <td align="left"><a href="/wiki/Illinois" title="Illinois">Illinois</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,720,546</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,695,598</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">6999925508922324480♠</span><font style="color:green">+0.93%</font></td>
# <td><span style="display:none" class="sortkey">7002227600000000000♠</span>227.6&#160;sq&#160;mi<br />
# 589.6&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7004118420000000000♠</span>11,842&#160;per&#160;sq&#160;mi<br />
# 4,572&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=41.8376_N_87.6818_W_&amp;title=3+Chicago"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">41°50′15″N</span> <span class="longitude">87°40′54″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">41.8376°N 87.6818°W</span><span style="display:none">﻿ / <span class="geo">41.8376; -87.6818</span></span><span style="display:none">﻿ (<span class="fn org">3 Chicago</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>4</td>
# <td align="left"><i><a href="/wiki/Houston" title="Houston">Houston</a></i><sup id="cite_ref-7" class="reference"><a href="#cite_note-7">[7]</a></sup></td>
# <td align="left"><a href="/wiki/Texas" title="Texas">Texas</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,296,224</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,100,263</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000933030768051430♠</span><font style="color:green">+9.33%</font></td>
# <td><span style="display:none" class="sortkey">7002599600000000000♠</span>599.6&#160;sq&#160;mi<br />
# 1,552.9&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003350100000000000♠</span>3,501&#160;per&#160;sq&#160;mi<br />
# 1,352&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=29.7805_N_95.3863_W_&amp;title=4+Houston"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">29°46′50″N</span> <span class="longitude">95°23′11″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">29.7805°N 95.3863°W</span><span style="display:none">﻿ / <span class="geo">29.7805; -95.3863</span></span><span style="display:none">﻿ (<span class="fn org">4 Houston</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>5</td>
# <td align="left"><i><a href="/wiki/Philadelphia" title="Philadelphia">Philadelphia</a></i><sup id="cite_ref-PhiladelphiaPA_8-0" class="reference"><a href="#cite_note-PhiladelphiaPA-8">[8]</a></sup></td>
# <td align="left"><a href="/wiki/Pennsylvania" title="Pennsylvania">Pennsylvania</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,567,442</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,526,006</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000271532353083800♠</span><font style="color:green">+2.72%</font></td>
# <td><span style="display:none" class="sortkey">7002134100000000000♠</span>134.1&#160;sq&#160;mi<br />
# 347.3&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7004113790000000000♠</span>11,379&#160;per&#160;sq&#160;mi<br />
# 4,394&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=40.0094_N_75.1333_W_&amp;title=5+Philadelphia"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">40°00′34″N</span> <span class="longitude">75°08′00″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">40.0094°N 75.1333°W</span><span style="display:none">﻿ / <span class="geo">40.0094; -75.1333</span></span><span style="display:none">﻿ (<span class="fn org">5 Philadelphia</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>6</td>
# <td align="left"><i><b><a href="/wiki/Phoenix,_Arizona" title="Phoenix, Arizona">Phoenix</a></b></i></td>
# <td align="left"><a href="/wiki/Arizona" title="Arizona">Arizona</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,563,025</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,445,632</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000812053136621220♠</span><font style="color:green">+8.12%</font></td>
# <td><span style="display:none" class="sortkey">7002516700000000000♠</span>516.7&#160;sq&#160;mi<br />
# 1,338.3&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003279800000000000♠</span>2,798&#160;per&#160;sq&#160;mi<br />
# 1,080&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=33.5722_N_112.0880_W_&amp;title=6+Phoenix"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">33°34′20″N</span> <span class="longitude">112°05′17″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">33.5722°N 112.0880°W</span><span style="display:none">﻿ / <span class="geo">33.5722; -112.0880</span></span><span style="display:none">﻿ (<span class="fn org">6 Phoenix</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>7</td>
# <td align="left"><a href="/wiki/San_Antonio" title="San Antonio">San Antonio</a></td>
# <td align="left"><a href="/wiki/Texas" title="Texas">Texas</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,469,845</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,327,407</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001107305445880580♠</span><font style="color:green">+10.73%</font></td>
# <td><span style="display:none" class="sortkey">7002460900000000000♠</span>460.9&#160;sq&#160;mi<br />
# 1,193.8&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003288000000000000♠</span>2,880&#160;per&#160;sq&#160;mi<br />
# 1,112&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=29.4724_N_98.5251_W_&amp;title=7+San+Antonio"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">29°28′21″N</span> <span class="longitude">98°31′30″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">29.4724°N 98.5251°W</span><span style="display:none">﻿ / <span class="geo">29.4724; -98.5251</span></span><span style="display:none">﻿ (<span class="fn org">7 San Antonio</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>8</td>
# <td align="left"><a href="/wiki/San_Diego" title="San Diego">San Diego</a></td>
# <td align="left"><a href="/wiki/California" title="California">California</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,394,928</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,307,402</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000669465091838620♠</span><font style="color:green">+6.69%</font></td>
# <td><span style="display:none" class="sortkey">7002325200000000000♠</span>325.2&#160;sq&#160;mi<br />
# 842.2&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003402000000000000♠</span>4,020&#160;per&#160;sq&#160;mi<br />
# 1,552&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=32.8153_N_117.1350_W_&amp;title=8+San+Diego"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">32°48′55″N</span> <span class="longitude">117°08′06″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">32.8153°N 117.1350°W</span><span style="display:none">﻿ / <span class="geo">32.8153; -117.1350</span></span><span style="display:none">﻿ (<span class="fn org">8 San Diego</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>9</td>
# <td align="left"><a href="/wiki/Dallas" title="Dallas">Dallas</a></td>
# <td align="left"><a href="/wiki/Texas" title="Texas">Texas</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,300,092</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,197,816</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000853854014306040♠</span><font style="color:green">+8.54%</font></td>
# <td><span style="display:none" class="sortkey">7002340500000000000♠</span>340.5&#160;sq&#160;mi<br />
# 881.9&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003351800000000000♠</span>3,518&#160;per&#160;sq&#160;mi<br />
# 1,358&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=32.7757_N_96.7967_W_&amp;title=9+Dallas"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">32°46′33″N</span> <span class="longitude">96°47′48″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">32.7757°N 96.7967°W</span><span style="display:none">﻿ / <span class="geo">32.7757; -96.7967</span></span><span style="display:none">﻿ (<span class="fn org">9 Dallas</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>10</td>
# <td align="left"><a href="/wiki/San_Jose,_California" title="San Jose, California">San Jose</a></td>
# <td align="left"><a href="/wiki/California" title="California">California</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,026,908</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">945,942</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000855929856164540♠</span><font style="color:green">+8.56%</font></td>
# <td><span style="display:none" class="sortkey">7002176600000000000♠</span>176.6&#160;sq&#160;mi<br />
# 457.3&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003535900000000000♠</span>5,359&#160;per&#160;sq&#160;mi<br />
# 2,069&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=37.2969_N_121.8193_W_&amp;title=10+San+Jose"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">37°17′49″N</span> <span class="longitude">121°49′09″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">37.2969°N 121.8193°W</span><span style="display:none">﻿ / <span class="geo">37.2969; -121.8193</span></span><span style="display:none">﻿ (<span class="fn org">10 San Jose</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>11</td>
# <td align="left"><b><a href="/wiki/Austin,_Texas" title="Austin, Texas">Austin</a></b></td>
# <td align="left"><a href="/wiki/Texas" title="Texas">Texas</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">931,830</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">790,390</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001178949632459920♠</span><font style="color:green">+17.89%</font></td>
# <td><span style="display:none" class="sortkey">7002322480000000000♠</span>322.48&#160;sq&#160;mi<br />
# 835.2&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003265300000000000♠</span>2,653&#160;per&#160;sq&#160;mi<br />
# 1,024&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=30.3072_N_97.7560_W_&amp;title=11+Austin"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">30°18′26″N</span> <span class="longitude">97°45′22″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">30.3072°N 97.7560°W</span><span style="display:none">﻿ / <span class="geo">30.3072; -97.7560</span></span><span style="display:none">﻿ (<span class="fn org">11 Austin</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>12</td>
# <td align="left"><i><a href="/wiki/Jacksonville,_Florida" title="Jacksonville, Florida">Jacksonville</a></i><sup id="cite_ref-JacksonvilleFL_9-0" class="reference"><a href="#cite_note-JacksonvilleFL-9">[9]</a></sup></td>
# <td align="left"><a href="/wiki/Florida" title="Florida">Florida</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">868,031</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">821,784</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000562763451223190♠</span><font style="color:green">+5.63%</font></td>
# <td><span style="display:none" class="sortkey">7002747000000000000♠</span>747.0&#160;sq&#160;mi<br />
# 1,934.7&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7003112000000000000♠</span>1,120&#160;per&#160;sq&#160;mi<br />
# 433&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=30.3370_N_81.6613_W_&amp;title=12+Jacksonville"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">30°20′13″N</span> <span class="longitude">81°39′41″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">30.3370°N 81.6613°W</span><span style="display:none">﻿ / <span class="geo">30.3370; -81.6613</span></span><span style="display:none">﻿ (<span class="fn org">12 Jacksonville</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>13</td>
# <td align="left"><a href="/wiki/San_Francisco" title="San Francisco">San Francisco</a><sup id="cite_ref-SanFranciscoCA_10-0" class="reference"><a href="#cite_note-SanFranciscoCA-10">[10]</a></sup></td>
# <td align="left"><a href="/wiki/California" title="California">California</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">864,816</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">805,235</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000739920644283970♠</span><font style="color:green">+7.40%</font></td>
# <td><span style="display:none" class="sortkey">7001469000000000000♠</span>46.9&#160;sq&#160;mi<br />
# 121.4&#160;km<sup>2</sup></td>
# <td><span style="display:none" class="sortkey">7004171790000000000♠</span>17,179&#160;per&#160;sq&#160;mi<br />
# 6,633&#160;km<sup>−2</sup></td>
# <td><small><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=37.7751_N_122.4193_W_&amp;title=13+San+Francisco"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">37°46′30″N</span> <span class="longitude">122°25′09″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">37.7751°N 122.4193°W</span><span style="display:none">﻿ / <span class="geo">37.7751; -122.4193</span></span><span style="display:none">﻿ (<span class="fn org">13 San Francisco</span>)</span></span></span></a></span></small></td>
# </tr>
# <tr>
# <td>14</td>
# <td align="left"><i><b><a href="/wiki/Indianapolis" title="Indianapolis">Indianapolis</a></b></i><sup id="cite_ref-IndianapolisIN_11-0" class="reference"><a href="#cite_note-IndianapolisIN-11">[11]</a></sup></td>
# <td align="left"><a href="/wiki/Indiana" title="Indiana">Indiana</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">853,173</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">820,445</td>
# ...
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/List_of_United_States_cities_by_population" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/List_of_United_States_cities_by_population" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=List_of_United_States_cities_by_population&amp;oldid=735363804" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=List_of_United_States_cities_by_population&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q131079" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_United_States_cities_by_population&amp;id=735363804" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=List+of+United+States+cities+by+population">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=List+of+United+States+cities+by+population&amp;returnto=List+of+United+States+cities+by+population&amp;oldid=735363804&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=List_of_United_States_cities_by_population&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-af"><a href="https://af.wikipedia.org/wiki/Lys_van_nedersettings_in_die_Verenigde_State_van_Amerika" title="Lys van nedersettings in die Verenigde State van Amerika – Afrikaans" lang="af" hreflang="af">Afrikaans</a></li><li class="interlanguage-link interwiki-ang"><a href="https://ang.wikipedia.org/wiki/Byrig_%C3%BE%C4%81ra_Ge%C4%81ndena_R%C4%ABca" title="Byrig þāra Geāndena Rīca – Old English" lang="ang" hreflang="ang">Ænglisc</a></li><li class="interlanguage-link interwiki-ar"><a href="https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D9%85%D8%AF%D9%86_%D8%A7%D9%84%D9%88%D9%84%D8%A7%D9%8A%D8%A7%D8%AA_%D8%A7%D9%84%D9%85%D8%AA%D8%AD%D8%AF%D8%A9_%D8%AD%D8%B3%D8%A8_%D8%B9%D8%AF%D8%AF_%D8%A7%D9%84%D8%B3%D9%83%D8%A7%D9%86" title="قائمة مدن الولايات المتحدة حسب عدد السكان – Arabic" lang="ar" hreflang="ar">العربية</a></li><li class="interlanguage-link interwiki-az"><a href="https://az.wikipedia.org/wiki/%C6%8Fhalisinin_say%C4%B1na_g%C3%B6r%C9%99_AB%C5%9E_%C5%9F%C9%99h%C9%99rl%C9%99rinin_siyah%C4%B1s%C4%B1" title="Əhalisinin sayına görə ABŞ şəhərlərinin siyahısı – Azerbaijani" lang="az" hreflang="az">Azərbaycanca</a></li><li class="interlanguage-link interwiki-be-x-old"><a href="https://be-x-old.wikipedia.org/wiki/%D0%A1%D1%8C%D0%BF%D1%96%D1%81_%D0%B3%D0%B0%D1%80%D0%B0%D0%B4%D0%BE%D1%9E_%D0%97%D0%A8%D0%90" title="Сьпіс гарадоў ЗША – беларуская (тарашкевіца)‎" lang="be-x-old" hreflang="be-x-old">Беларуская (тарашкевіца)‎</a></li><li class="interlanguage-link interwiki-bg"><a href="https://bg.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D1%8A%D0%BA_%D0%BD%D0%B0_%D0%B3%D1%80%D0%B0%D0%B4%D0%BE%D0%B2%D0%B5%D1%82%D0%B5_%D0%B2_%D0%A1%D0%90%D0%A9_%D0%BF%D0%BE_%D0%BD%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5" title="Списък на градовете в САЩ по население – Bulgarian" lang="bg" hreflang="bg">Български</a></li><li class="interlanguage-link interwiki-bar"><a href="https://bar.wikipedia.org/wiki/St%C3%A4dt_in_da_USA" title="Städt in da USA – Bavarian" lang="bar" hreflang="bar">Boarisch</a></li><li class="interlanguage-link interwiki-bs"><a href="https://bs.wikipedia.org/wiki/Abecedni_spisak_mjesta_u_SAD-u/A" title="Abecedni spisak mjesta u SAD-u/A – Bosnian" lang="bs" hreflang="bs">Bosanski</a></li><li class="interlanguage-link interwiki-ca"><a href="https://ca.wikipedia.org/wiki/Llista_de_ciutats_dels_Estats_Units_per_poblaci%C3%B3" title="Llista de ciutats dels Estats Units per població – Catalan" lang="ca" hreflang="ca">Català</a></li><li class="interlanguage-link interwiki-cs"><a href="https://cs.wikipedia.org/wiki/Seznam_m%C4%9Bst_USA_podle_po%C4%8Dtu_obyvatel" title="Seznam měst USA podle počtu obyvatel – Czech" lang="cs" hreflang="cs">Čeština</a></li><li class="interlanguage-link interwiki-da"><a href="https://da.wikipedia.org/wiki/USA%27s_st%C3%B8rste_byer" title="USA's største byer – Danish" lang="da" hreflang="da">Dansk</a></li><li class="interlanguage-link interwiki-de"><a href="https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_den_Vereinigten_Staaten" title="Liste der Städte in den Vereinigten Staaten – German" lang="de" hreflang="de">Deutsch</a></li><li class="interlanguage-link interwiki-el"><a href="https://el.wikipedia.org/wiki/%CE%9A%CE%B1%CF%84%CE%AC%CE%BB%CE%BF%CE%B3%CE%BF%CF%82_%CF%80%CF%8C%CE%BB%CE%B5%CF%89%CE%BD_%CF%84%CF%89%CE%BD_%CE%97%CE%BD%CF%89%CE%BC%CE%AD%CE%BD%CF%89%CE%BD_%CE%A0%CE%BF%CE%BB%CE%B9%CF%84%CE%B5%CE%B9%CF%8E%CE%BD_%CE%B1%CE%BD%CE%AC_%CF%80%CE%BB%CE%B7%CE%B8%CF%85%CF%83%CE%BC%CF%8C" title="Κατάλογος πόλεων των Ηνωμένων Πολιτειών ανά πληθυσμό – Greek" lang="el" hreflang="el">Ελληνικά</a></li><li class="interlanguage-link interwiki-es"><a href="https://es.wikipedia.org/wiki/Anexo:Ciudades_de_Estados_Unidos_por_poblaci%C3%B3n" title="Anexo:Ciudades de Estados Unidos por población – Spanish" lang="es" hreflang="es">Español</a></li><li class="interlanguage-link interwiki-eo"><a href="https://eo.wikipedia.org/wiki/Listo_de_urboj_de_Usono" title=" ...
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q131079#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 20 August 2016, at 06:22.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=List_of_United_States_cities_by_population&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","mmv.bootstrap.autostart","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interlanguage","ext.centralNotice.startUp","ext.centralNotice.geoIP"]);});</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set( {
#     "wgPageParseReport": {
#         "limitreport": {
#             "cputime": "4.922",
#             "walltime": "5.173",
#             "ppvisitednodes": {
#                 "value": 140884,
#                 "limit": 1000000
#             },
#             "ppgeneratednodes": {
#                 "value": 0,
#                 "limit": 1500000
#             },
#             "postexpandincludesize": {
#                 "value": 1234451,
#                 "limit": 2097152
#             },
#             "templateargumentsize": {
#                 "value": 153081,
#                 "limit": 2097152
#             },
#             "expansiondepth": {
#                 "value": 15,
#                 "limit": 40
#             },
#             "expensivefunctioncount": {
#                 "value": 2,
#                 "limit": 500
#             },
#             "timingprofile": [
#                 "100.00% 3501.027      1 -total",
#                 " 36.77% 1287.365    317 Template:Change",
#                 " 34.84% 1219.841    317 Template:Change/rowIonSoff",
#                 " 28.53%  998.689    688 Template:Nts",
#                 " 26.06%  912.336    317 Template:Change/outIonSon",
#                 " 21.35%  747.521    688 Template:Number_table_sorting/Qno/Fyes/Sno/0",
#                 " 19.27%  674.738    317 Template:Coord",
#                 " 10.87%  380.468    316 Template:Ntsh",
#                 "  6.83%  238.979    289 Template:Number_table_sorting/Qyes/0",
#                 "  2.98%  104.249      1 Template:Reflist"
#             ]
#         },
#         "scribunto": {
#             "limitreport-timeusage": {
#                 "value": "0.868",
#                 "limit": "10.000"
#             },
#             "limitreport-memusage": {
#                 "value": 5891046,
#                 "limit": 52428800
#             }
#         },
#         "EntityAccessCount": 0,
#         "cachereport": {
#             "origin": "mw1186",
#             "timestamp": "20160820095849",
#             "ttl": 2592000,
#             "transientcontent": false
#         }
#     }
# } );});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":87,"wgHostname":"mw1246"});});</script>
# 	</body>
# </html>

# %%
line1 = Selector(text=HTML).xpath("//table[@class='wikitable sortable']/tr/td[2]/a/text()").extract()

#print line
top_cities = [x.encode('utf-8') for x in line1]
print top_cities
# Out:
# ['San Antonio', 'San Diego', 'Dallas', 'San Jose', 'San Francisco', 'Fort Worth', 'El Paso', 'Tucson', 'Fresno', 'Long Beach', 'Mesa', 'Colorado Springs', 'Miami', 'Oakland', 'Tulsa', 'Arlington', 'Cleveland', 'Bakersfield', 'Tampa', 'Aurora', 'Anaheim', 'Santa Ana', 'Corpus Christi', 'Riverside', 'St. Louis', 'Lexington', 'Stockton', 'Pittsburgh', 'Cincinnati', 'Henderson', 'Greensboro', 'Plano', 'Toledo', 'Orlando', 'Chula Vista', 'Jersey City', 'Chandler', 'Fort Wayne', 'Buffalo', 'Durham', 'St. Petersburg', 'Irvine', 'Laredo', 'Lubbock', 'Gilbert', 'Norfolk', 'Reno', 'Winston\xe2\x80\x93Salem', 'Glendale', 'Hialeah', 'Garland', 'Scottsdale', 'Irving', 'Chesapeake', 'North Las Vegas', 'Fremont', 'San Bernardino', 'Spokane', 'Modesto', 'Rochester', 'Tacoma', 'Fontana', 'Oxnard', 'Moreno Valley', 'Fayetteville', 'Huntington Beach', 'Yonkers', 'Glendale', 'Aurora', 'Columbus', 'Amarillo', 'Akron', 'Shreveport', 'Augusta', 'Grand Rapids', 'Mobile', 'Huntsville', 'Grand Prairie', 'Overland Park', 'Knoxville', 'Worcester', 'Brownsville', 'Newport News', 'Santa Clarita', 'Port St. Lucie', 'Fort Lauderdale', 'Chattanooga', 'Tempe', 'Oceanside', 'Garden Grove', 'Rancho Cucamonga', 'Cape Coral', 'Santa Rosa', 'Vancouver', 'Peoria', 'Ontario', 'Elk Grove', 'Springfield', 'Pembroke Pines', 'Corona', 'Eugene', 'McKinney', 'Fort Collins', 'Lancaster', 'Cary', 'Palmdale', 'Hayward', 'Salinas', 'Frisco', 'Springfield', 'Pasadena', 'Macon', 'Alexandria', 'Pomona', 'Lakewood', 'Sunnyvale', 'Escondido', 'Kansas City', 'Hollywood', 'Clarksville', 'Torrance', 'Rockford', 'Joliet', 'Paterson', 'Naperville', 'Savannah', 'Mesquite', 'Syracuse', 'Pasadena', 'Orange', 'Fullerton', 'Killeen', 'Dayton', 'McAllen', 'Bellevue', 'Miramar', 'Hampton', 'West Valley City', 'Warren', 'Olathe', 'Thornton', 'Carrollton', 'Midland', 'Charleston', 'Waco', 'Sterling Heights', 'Denton', 'Cedar Rapids', 'New Haven', 'Roseville', 'Gainesville', 'Visalia', 'Coral Springs', 'Thousand Oaks', 'Elizabeth', 'Stamford', 'Concord', 'Surprise', 'Lafayette', 'Kent', 'Simi Valley', 'Santa Clara', 'Murfreesboro', 'Athens', 'Victorville', 'Abilene', 'Vallejo', 'Berkeley', 'Norman', 'Allentown', 'Evansville', 'Columbia', 'Odessa', 'Beaumont', 'Independence', 'Ann Arbor', 'El Monte', 'Round Rock', 'Wilmington', 'Arvada', 'Provo', 'Peoria', 'Downey', 'Carlsbad', 'Costa Mesa', 'Miami Gardens', 'Westminster', 'Clearwater', 'Fairfield', 'Rochester', 'Elgin', 'Temecula', 'West Jordan', 'Inglewood', 'Richardson', 'Lowell', 'Gresham', 'Antioch', 'Cambridge', 'High Point', 'Murrieta', 'Centennial', 'Richmond', 'Ventura', 'Pueblo', 'Pearland', 'Waterbury', 'West Covina', 'North Charleston', 'Everett', 'College Station', 'Palm Bay', 'Pompano Beach', 'Boulder', 'Norwalk', 'West Palm Beach', 'Broken Arrow', 'Daly City', 'Sandy Springs', 'Burbank', 'Green Bay', 'Santa Maria', 'Wichita Falls', 'Lakeland', 'Clovis', 'Lewisville', 'Tyler', 'El Cajon', 'San Mateo', 'Rialto', 'Edison', 'Davenport', 'Hillsboro', 'Woodbridge', 'Las Cruces', 'South Bend', 'Vista', 'Greeley', 'Davie', 'San Angelo', 'Jurupa Valley', 'Renton', 'Bayam\xc3\xb3n', 'Carolina', 'Ponce', 'Caguas', 'Nevada', 'Virginia', 'Nevada', 'Nevada', 'Louisiana', 'California', 'Nevada', 'Florida', 'New York', 'Pennsylvania', 'New York', 'New Jersey', 'Ohio', 'Michigan', 'Minnesota', 'Pennsylvania', 'Massachusetts', 'Michigan', 'Indiana', 'Indiana', 'Wisconsin', 'Michigan', 'Massachusetts', 'Massachusetts', 'New York', 'Ohio', 'Virginia', 'Pennsylvania', 'Virginia', 'Pennsylvania', 'Massachusetts', 'Missouri', 'New Jersey', 'New York', 'Delaware', 'Ohio']

# %%
print len(top_cities)
# Out:
# 282

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1.2 Only retain cities with properly formed ASCII
#
# Optionally, filter out any cities with impropper ASCII characters.  A smaller list will be easier to look at.  However you may not need to filter these if you spend more time scraping a more concise city list.  This list should help you narrow down the list of regional Craigslist sites.

# %%
# ONLY RETAIN PROPERLY FORMED CITIES WITH FILTERING FUNCTION
ascii_cities = []
for x in line1:
    try:
            x.decode('ascii')
            ascii_cities.append(x.replace(' ','').encode('utf-8'))
    except:
        print '=========error ', x
print ascii_cities
# Out:
# =========error  Winston–Salem
# =========error  Bayamón
# ['SanAntonio', 'SanDiego', 'Dallas', 'SanJose', 'SanFrancisco', 'FortWorth', 'ElPaso', 'Tucson', 'Fresno', 'LongBeach', 'Mesa', 'ColoradoSprings', 'Miami', 'Oakland', 'Tulsa', 'Arlington', 'Cleveland', 'Bakersfield', 'Tampa', 'Aurora', 'Anaheim', 'SantaAna', 'CorpusChristi', 'Riverside', 'St.Louis', 'Lexington', 'Stockton', 'Pittsburgh', 'Cincinnati', 'Henderson', 'Greensboro', 'Plano', 'Toledo', 'Orlando', 'ChulaVista', 'JerseyCity', 'Chandler', 'FortWayne', 'Buffalo', 'Durham', 'St.Petersburg', 'Irvine', 'Laredo', 'Lubbock', 'Gilbert', 'Norfolk', 'Reno', 'Glendale', 'Hialeah', 'Garland', 'Scottsdale', 'Irving', 'Chesapeake', 'NorthLasVegas', 'Fremont', 'SanBernardino', 'Spokane', 'Modesto', 'Rochester', 'Tacoma', 'Fontana', 'Oxnard', 'MorenoValley', 'Fayetteville', 'HuntingtonBeach', 'Yonkers', 'Glendale', 'Aurora', 'Columbus', 'Amarillo', 'Akron', 'Shreveport', 'Augusta', 'GrandRapids', 'Mobile', 'Huntsville', 'GrandPrairie', 'OverlandPark', 'Knoxville', 'Worcester', 'Brownsville', 'NewportNews', 'SantaClarita', 'PortSt.Lucie', 'FortLauderdale', 'Chattanooga', 'Tempe', 'Oceanside', 'GardenGrove', 'RanchoCucamonga', 'CapeCoral', 'SantaRosa', 'Vancouver', 'Peoria', 'Ontario', 'ElkGrove', 'Springfield', 'PembrokePines', 'Corona', 'Eugene', 'McKinney', 'FortCollins', 'Lancaster', 'Cary', 'Palmdale', 'Hayward', 'Salinas', 'Frisco', 'Springfield', 'Pasadena', 'Macon', 'Alexandria', 'Pomona', 'Lakewood', 'Sunnyvale', 'Escondido', 'KansasCity', 'Hollywood', 'Clarksville', 'Torrance', 'Rockford', 'Joliet', 'Paterson', 'Naperville', 'Savannah', 'Mesquite', 'Syracuse', 'Pasadena', 'Orange', 'Fullerton', 'Killeen', 'Dayton', 'McAllen', 'Bellevue', 'Miramar', 'Hampton', 'WestValleyCity', 'Warren', 'Olathe', 'Thornton', 'Carrollton', 'Midland', 'Charleston', 'Waco', 'SterlingHeights', 'Denton', 'CedarRapids', 'NewHaven', 'Roseville', 'Gainesville', 'Visalia', 'CoralSprings', 'ThousandOaks', 'Elizabeth', 'Stamford', 'Concord', 'Surprise', 'Lafayette', 'Kent', 'SimiValley', 'SantaClara', 'Murfreesboro', 'Athens', 'Victorville', 'Abilene', 'Vallejo', 'Berkeley', 'Norman', 'Allentown', 'Evansville', 'Columbia', 'Odessa', 'Beaumont', 'Independence', 'AnnArbor', 'ElMonte', 'RoundRock', 'Wilmington', 'Arvada', 'Provo', 'Peoria', 'Downey', 'Carlsbad', 'CostaMesa', 'MiamiGardens', 'Westminster', 'Clearwater', 'Fairfield', 'Rochester', 'Elgin', 'Temecula', 'WestJordan', 'Inglewood', 'Richardson', 'Lowell', 'Gresham', 'Antioch', 'Cambridge', 'HighPoint', 'Murrieta', 'Centennial', 'Richmond', 'Ventura', 'Pueblo', 'Pearland', 'Waterbury', 'WestCovina', 'NorthCharleston', 'Everett', 'CollegeStation', 'PalmBay', 'PompanoBeach', 'Boulder', 'Norwalk', 'WestPalmBeach', 'BrokenArrow', 'DalyCity', 'SandySprings', 'Burbank', 'GreenBay', 'SantaMaria', 'WichitaFalls', 'Lakeland', 'Clovis', 'Lewisville', 'Tyler', 'ElCajon', 'SanMateo', 'Rialto', 'Edison', 'Davenport', 'Hillsboro', 'Woodbridge', 'LasCruces', 'SouthBend', 'Vista', 'Greeley', 'Davie', 'SanAngelo', 'JurupaValley', 'Renton', 'Carolina', 'Ponce', 'Caguas', 'Nevada', 'Virginia', 'Nevada', 'Nevada', 'Louisiana', 'California', 'Nevada', 'Florida', 'NewYork', 'Pennsylvania', 'NewYork', 'NewJersey', 'Ohio', 'Michigan', 'Minnesota', 'Pennsylvania', 'Massachusetts', 'Michigan', 'Indiana', 'Indiana', 'Wisconsin', 'Michigan', 'Massachusetts', 'Massachusetts', 'NewYork', 'Ohio', 'Virginia', 'Pennsylvania', 'Virginia', 'Pennsylvania', 'Massachusetts', 'Missouri', 'NewJersey', 'NewYork', 'Delaware', 'Ohio']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2.  Write a function to capture current pricing information via Craigslist in one city.
# Choose a city from your scraped data, then go to the cooresponding city section on Craigslist, searching for "rv" in the auto section.  Write a method that pulls out the prices.

# %%
print HTML
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
#     <title>richmond, VA recreational vehicles  - craigslist</title>
#
#     <meta name="description" content="richmond, VA recreational vehicles  - craigslist">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#     <link rel="canonical" href="https://richmond.craigslist.org/search/rva">
#     <link rel="alternate" type="application/rss+xml" href="https://richmond.craigslist.org/search/rva?format=rss" title="RSS feed for craigslist | richmond, VA recreational vehicles  - craigslist ">
#
#     <link rel="next" href="https://richmond.craigslist.org/search/rva?s=100">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=8bdb0cf3d743129c14696bf6f621f16f">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=af75b8cc1e45fb421a5858821aadf330">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=31607a98a2cb3fba2c70e3e66ecb4440">
#     <link rel="prefetch" href="//www.craigslist.org/js/postings-concat.min.js?v=fa24a444d1d09fbf00612e8074ca2b50">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=52966d0fad2afe8dd918e5f48abb0db3">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=c9937ed03fbb57f185493cd8c283efeb">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=e1c93c9e4b8d31fc183c0dff0c70e0b7">
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#
#         <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "60";
# var areaRegion = "VA";
# var catAbb = "rva";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageHost = "https://images.craigslist.org";
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 2500;
# var noImageText = "no image";
# var pID = null;
# var purveyorCategories = {"owner":"rvs","dealer":"rvd","all":"rva"};
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
#
#     <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=096822b653643ed1af3136947e4ea79a" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=d7e1cb0d97ee0c0c9d84a7d4f1d03469" type="text/javascript" ></script>
#
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=178d4ad319e0e0b4a451b15e49b71bec" type="text/javascript" ></script>
#
# <![endif]-->
# </head>
# <body class="search en">
#     <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
#
#
#     <section id="pagecontainer">
#         <div class="bglogo"></div>
#         <header class="global-header">
#    <a class="header-logo" href="/">CL</a>
#
#     <nav class="breadcrumbs-container">
# <form id="breadcrumbform" class="breadcrumbs-form" method="get" action="/search/rva" data-action="/search/###/rva">
#
#     <ul class="breadcrumbs">
#         <li class="crumb area">
#
#             <span class="no-js">
#                 <a href="/">richmond, VA</a>
#             </span>
#                 <select name="areaAbb" id="areaAbb" class="js-only">
#                     <option value="richmond">richmond, VA</option>
#                         <option value="altoona">altoona</option>
#                         <option value="annapolis">annapolis</option>
#                         <option value="baltimore">baltimore</option>
#                         <option value="blacksburg">blacksburg</option>
#                         <option value="charlottesville">charlottesville</option>
#                         <option value="chambersburg">cumberland val</option>
#                         <option value="danville">danville</option>
#                         <option value="delaware">delaware</option>
#                         <option value="eastnc">eastern NC</option>
#                         <option value="easternshore">eastern shore</option>
#                         <option value="martinsburg">eastern WV</option>
#                         <option value="fayetteville">fayetteville, NC</option>
#                         <option value="frederick">frederick</option>
#                         <option value="fredericksburg">fredericksburg</option>
#                         <option value="greensboro">greensboro</option>
#                         <option value="harrisburg">harrisburg</option>
#                         <option value="harrisonburg">harrisonburg</option>
#                         <option value="onslow">jacksonville, NC</option>
#                         <option value="lancaster">lancaster, PA</option>
#                         <option value="lynchburg">lynchburg</option>
#                         <option value="morgantown">morgantown</option>
#                         <option value="norfolk">norfolk</option>
#                         <option value="outerbanks">outer banks</option>
#                         <option value="philadelphia">philadelphia</option>
#                         <option value="raleigh">raleigh</option>
#                         <option value="reading">reading</option>
#                         <option value="roanoke">roanoke</option>
#                         <option value="southjersey">south jersey</option>
#                         <option value="smd">southern MD</option>
#                         <option value="swv">southern WV</option>
#                         <option value="pennstate">state college</option>
#                         <option value="washingtondc">washington, DC</option>
#                         <option value="wv">west virginia</option>
#                         <option value="westmd">western MD</option>
#                         <option value="wilmington">wilmington, NC</option>
#                         <option value="winchester">winchester</option>
#                         <option value="winstonsalem">winston-salem</option>
#                         <option value="york">york, PA</option>
#                 </select>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb section">
#                     <select name="catAbb" id="catAbb">
#                         <option value="ccc">community</option>
#                         <option value="eee">events</option>
#                         <option value="sss" selected>for sale</option>
#                         <option value="ggg">gigs</option>
#                         <option value="hhh">housing</option>
#                         <option value="jjj">jobs</option>
#                         <option value="ppp">personals</option>
#                         <option value="rrr">resumes</option>
#                         <option value="bbb">services</option>
#                     </select>
#                 <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb category">
#             <select id="subcatAbb" class="js-only">
#                 <option value="sss">all</option>
#                     <option value="ata">antiques</option>
#                     <option value="ppa">appliances</option>
#                     <option value="ara">arts+crafts</option>
#                     <option value="sna">atvs/utvs/snow</option>
#                     <option value="pta">auto parts</option>
#                     <option value="wta">auto wheels &amp; tires</option>
#                     <option value="baa">baby+kids</option>
#                     <option value="bar">barter</option>
#                     <option value="haa">beauty+hlth</option>
#                     <option value="bip">bike parts</option>
#                     <option value="bia">bikes</option>
#                     <option value="bpa">boat parts</option>
#                     <option value="boo">boats</option>
#                     <option value="bka">books</option>
#                     <option value="bfa">business</option>
#                     <option value="cta">cars+trucks</option>
#                     <option value="ema">cds/dvd/vhs</option>
#                     <option value="moa">cell phones</option>
#                     <option value="cla">clothes+acc</option>
#                     <option value="cba">collectibles</option>
#                     <option value="syp">computer parts</option>
#                     <option value="sya">computers</option>
#                     <option value="ela">electronics</option>
#                     <option value="gra">farm+garden</option>
#                     <option value="zip">free stuff</option>
#                     <option value="fua">furniture</option>
#                     <option value="gms">garage sales</option>
#                     <option value="foa">general</option>
#                     <option value="hva">heavy equipment</option>
#                     <option value="hsa">household</option>
#                     <option value="jwa">jewelry</option>
#                     <option value="maa">materials</option>
#                     <option value="mpa">motorcycle parts</option>
#                     <option value="mca">motorcycles</option>
#                     <option value="msa">music instr</option>
#                     <option value="pha">photo+video</option>
#                     <option value="rva" selected>RVs</option>
#                     <option value="sga">sporting</option>
#                     <option value="tia">tickets</option>
#                     <option value="tla">tools</option>
#                     <option value="taa">toys+games</option>
#                     <option value="tra">trailers</option>
#                     <option value="vga">video gaming</option>
#                     <option value="waa">wanted</option>
#             </select><span class="no-js">RVs</span>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb no-js">
#             <input type="submit" value="go">
#         </li>
#     </ul>
# </form>
#     </nav>
#
# <div class="userlinks">
#     <ul class="user-actions">
#         <li class="user post">
#             <a href="https://post.craigslist.org/c/ric">post</a>
#         </li>
#         <li class="user account">
#             <a href="https://accounts.craigslist.org/login/home">account</a>
#         </li>
#     </ul>
#     <ul class="user-favs-discards">
#         <li class="user">
#             <div class="favorites">
#                 <a href="#" class="favlink"><span class="icon icon-star fav" aria-hidden="true"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
#             </div>
#         </li>
#         <li class="user discards">
#           <form class="unfavform js-only" method="POST" action="/favorites">
#             <div class="to-banish-page">
#               <input type="hidden" class="lastLink" name="lastLink" value="//richmond.craigslist.org/search/rva">
#               <input type="hidden" class="lastTitle" name="lastTitle" value="richmond, VA recreational vehicles  - craigslist">
#               <input type="hidden" class="unfaves" name="fl">
#               <input type="hidden" name="uf" value="1">
#               <a href="#" class="to-banish-page-link">
#                 <span class="icon icon-trash red" aria-hidden="true"></span>
#                 <span class="banished_count">0</span>
#                 <span class="discards-label"> hidden</span>
#               </a>
#             </div>
#           </form>
#         </li>
#     </ul>
# </div>
# </header>
#
#
#         <form id="searchform" class="search-form" action="/search/rva"  >
#
#             <div class="querybox">
#
#                 <div class="form-tab js-only"><span class="search-open" title="hide search">&laquo;</span><span class="search-closed" title="show search">&raquo;</span></div>
#
#                 <input type="text" placeholder="search recreational vehicles" name="query"
#                     id="query" value="" autocorrect="off"
#                     autocapitalize="off" autocomplete="off" data-autocomplete="search"
#                     class="flatinput ui-autocomplete-input">
#
#                 <button type="submit" class="searchbtn">
#                     <span class="icon icon-search" aria-hidden="true"></span>
#                     <span class="screen-reader-text">press to search craigslist</span>
#                 </button>
#                 <div class="savealert">
#                             <a class="saveme" data-action="save"  href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Frichmond%252Ecraigslist%252Eorg%252Fsearch%252Frva"  title="save this search" >save search</a>
#                         </div>
#             </div>
#
#             <div class="search-options-container">
#     <h2 class="search-options-header linklike">
#         <div class="icon icon-toggle-gear" aria-hidden="true"></div>
#         options<span class="options-close">close</span>
#     </h2>
#     <input id="excats" type="hidden" name="excats">
#
#     <div class="search-options">
#         <div class="searchgroup categories">
#             <div class="cattitle">
#               <a href="/search/rva" title="clear all search parameters" class="reset">recreational vehicles</a>
#             </div>
#
#         </div>
#
#         <ul class="searchgroup buttongroup purveyor">
#     <li class="button sel"><a href="/search/rva" data-val="all">all</a></li><li class="button "><a href="/search/rvs" data-val="owner">owner</a></li><li class="button "><a href="/search/rvd" data-val="dealer">dealer</a></li>
# </ul>
#
#
#
#
#
#
#
#         <div class="searchgroup">
#             <ul><li><label class="srchType"><input type="checkbox" name="srchType" class="autosubmit" value="T" >search titles only</label></li><li><label class="hasPic"><input type="checkbox" name="hasPic" class="autosubmit" value="1" >has image</label></li><li><label class="postedToday"><input type="checkbox" name="postedToday" class="autosubmit" value="1" >posted today</label></li><li><label class="searchNearby"><input type="checkbox" name="searchNearby" class="autosubmit" value="1" >include nearby areas</label></li></ul>
#
#             <ul class="js-only nearbyAreas ">
#                 <li class="nearbyZone nearbyZone_5"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_35" value="355"  disabled="disabled">altoona-johnstown <small>(aoo)</small></label><li class="nearbyZone nearbyZone_1"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_7" value="460"  disabled="disabled">annapolis, MD <small>(anp)</small></label><li class="nearbyZone nearbyZone_8"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_53" value="438"  disabled="disabled">athens, OH <small>(ohu)</small></label><li class="nearbyZone nearbyZone_2"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_12" value="34"  disabled="disabled">baltimore, MD <small>(bal)</small></label><li class="nearbyZone nearbyZone_7"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_45" value="446"  disabled="disabled">boone, NC <small>(bnc)</small></label><li class="nearbyZone nearbyZone_6"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_41" value="349"  disabled="disabled">central NJ <small>(cnj)</small></label><li class="nearbyZone nearbyZone_6"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_38" value="439"  disabled="disabled">charleston, WV <small>(crw)</small></label><li class="nearbyZone nearbyZone_7"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_42" value="41"  disabled="disabled">charlotte, NC <small>(cha)</small></label><li class=""><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_1" value="290"  disabled="disabled">charlottesville, VA <small>(uva)</small></label><li class="nearbyZone nearbyZone_3"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_22" value="705"  disabled="disabled">cumberland valley <small>(cbg)</small></label><li class="nearbyZone nearbyZone_1"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_10" value="367"  disabled="disabled">danville <small>(dnv)</small></label><li class="nearbyZone nearbyZone_3"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_18" value="193"  disabled="disabled">delaware <small>(dlw)</small></label><li class="nearbyZone nearbyZone_9"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_59" value="674"  disabled="disabled">eastern kentucky <small>(eky)</small></label><li class="nearbyZone nearbyZone_2"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_13" value="335"  disabled="disabled">eastern NC <small>(enc)</small></label><li class="nearbyZone nearbyZone_2"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_14" value="444"  disabled="disabled">eastern panhandle <small>(ewv)</small></label><li class="nearbyZone nearbyZone_1"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_8" value="328"  disabled="disabled">eastern shore <small>(esh)</small></label><li class="nearbyZone nearbyZone_4"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_27" value="273"  disabled="disabled">fayetteville, NC <small>(fay)</small></label><li class="nearbyZone nearbyZone_8"><label class="nearby"><input type="checkbox" class="use-id nearbyArea" name="nearbyArea" id="nearbyArea_50" value="464"  disabled="disabled">florence, SC <small>(flo)</small></label><li class="nearbyZone nearbyZone_1"><label class="nearby"><input type ...
#             </ul>
#
#         </div>
#
#         <div class="searchgroup">
#         <span class="searchfieldlabel">miles from zip</span>
#         <input type="number" max="200" min="0" size="3" inputmode="numeric"
#             class="flatinput searchInput search_distance" placeholder="miles"
#             name="search_distance" value="">
#         <input type="text" class="flatinput searchInput postal" placeholder="from zip"
#                 size="7" name="postal" value="">
#     </div>
#
#
#
#         <div class="searchgroup minmax price">
#   <span class="searchfieldlabel">price</span> <input type="tel" name="min_price" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value=""> <input type="tel" name="max_price" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div>
#
#
#
#         <div class="searchgroup">  <span class="searchfieldlabel">make and model</span>
#   <input type="text" class="flatinput auto_make_model" placeholder="make / model" name="auto_make_model" data-autocomplete="makemodel" value=""></div><div class="searchgroup"><div class="minmax auto_year">
#   <span class="searchfieldlabel">model year</span> <input type="tel" name="min_auto_year" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value=""> <input type="tel" name="max_auto_year" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div><div class="minmax auto_miles">
#   <span class="searchfieldlabel">odometer</span> <input type="tel" name="min_auto_miles" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value=""> <input type="tel" name="max_auto_miles" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div></div><div class="searchgroup">      <div id="headerattr_condition" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="condition">
#         <span id="plusminus_condition" class="plusminus">+</span>condition
#       </div>
# <ul id="ul_condition" class="attr_list hideme">           <li class="attr_condition ">
#              <label data-attr="condition">
#                <input id="new_10" name="condition"
#                       class="multi_checkbox multi_condition" data-attr="condition"
#
#                       value="10" type="checkbox">
#                new
#              </label>
#            </li>
#            <li class="attr_condition ">
#              <label data-attr="condition">
#                <input id="like_new_20" name="condition"
#                       class="multi_checkbox multi_condition" data-attr="condition"
#
#                       value="20" type="checkbox">
#                like new
#              </label>
#            </li>
#            <li class="attr_condition ">
#              <label data-attr="condition">
#                <input id="excellent_30" name="condition"
#                       class="multi_checkbox multi_condition" data-attr="condition"
#
#                       value="30" type="checkbox">
#                excellent
#              </label>
#            </li>
#            <li class="attr_condition ">
#              <label data-attr="condition">
#                <input id="good_40" name="condition"
#                       class="multi_checkbox multi_condition" data-attr="condition"
#
#                       value="40" type="checkbox">
#                good
#              </label>
#            </li>
#            <li class="attr_condition ">
#              <label data-attr="condition">
#                <input id="fair_50" name="condition"
#                       class="multi_checkbox multi_condition" data-attr="condition"
#
#                       value="50" type="checkbox">
#                fair
#              </label>
#            </li>
#            <li class="attr_condition ">
#              <label data-attr="condition">
#                <input id="salvage_60" name="condition"
#                       class="multi_checkbox multi_condition" data-attr="condition"
#
#                       value="60" type="checkbox">
#                salvage
#              </label>
#            </li>
# </ul>      <div id="headerattr_auto_cylinders" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="auto_cylinders">
#         <span id="plusminus_auto_cylinders" class="plusminus">+</span>cylinders
#       </div>
# <ul id="ul_auto_cylinders" class="attr_list hideme">           <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="3_cylinders_1" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="1" type="checkbox">
#                3 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="4_cylinders_2" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="2" type="checkbox">
#                4 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="5_cylinders_3" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="3" type="checkbox">
#                5 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="6_cylinders_4" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="4" type="checkbox">
#                6 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="8_cylinders_5" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="5" type="checkbox">
#                8 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="10_cylinders_6" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="6" type="checkbox">
#                10 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="12_cylinders_7" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="7" type="checkbox">
#                12 cylinders
#              </label>
#            </li>
#            <li class="attr_auto_cylinders ">
#              <label data-attr="auto_cylinders">
#                <input id="other_8" name="auto_cylinders"
#                       class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#
#                       value="8" type="checkbox">
#                other
#              </label>
#            </li>
# <li class="selectall js-only attr_auto_cylinders "><label><input type="checkbox" data-attr="auto_cylinders" class="selectallcb multi_checkbox" > <span class="all select_all_auto_cylinders">select all</span><span class="none deselect_all_auto_cylinders">deselect all</span></label></li></ul>      <div id="headerattr_auto_drivetrain" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="auto_drivetrain">
#         <span id="plusminus_auto_drivetrain" class="plusminus">+</span>drive
#       </div>
# <ul id="ul_auto_drivetrain" class="attr_list hideme">           <li class="attr_auto_drivetrain ">
#              <label data-attr="auto_drivetrain">
#                <input id="fwd_1" name="auto_drivetrain"
#                       class="multi_checkbox multi_auto_drivetrain" data-attr="auto_drivetrain"
#
#                       value="1" type="checkbox">
#                fwd
#              </label>
#            </li>
#            <li class="attr_auto_drivetrain ">
#              <label data-attr="auto_drivetrain">
#                <input id="rwd_2" name="auto_drivetrain"
#                       class="multi_checkbox multi_auto_drivetrain" data-attr="auto_drivetrain"
#
#                       value="2" type="checkbox">
#                rwd
#              </label>
#            </li>
#            <li class="attr_auto_drivetrain ">
#              <label data-attr="auto_drivetrain">
#                <input id="4wd_3" name="auto_drivetrain"
#                       class="multi_checkbox multi_auto_drivetrain" data-attr="auto_drivetrain"
#
#                       value="3" type="checkbox">
#                4wd
#              </label>
#            </li>
# </ul>      <div id="headerattr_auto_fuel_type" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="auto_fuel_type">
#         <span id="plusminus_auto_fuel_type" class="plusminus">+</span>fuel
#       </div>
# <ul id="ul_auto_fuel_type" class="attr_list hideme">           <li class="attr_auto_fuel_type ">
#              <label data-attr="auto_fuel_type">
#                <input id="gas_1" name="auto_fuel_type"
#                       class="multi_checkbox multi_auto_fuel_type" data-attr="auto_fuel_type"
#
#                       value="1" type="checkbox">
#                gas
#              </label>
#            </li>
#            <li class="attr_auto_fuel_type ">
#              <label data-attr="auto_fuel_type">
#                <input id="diesel_2" name="auto_fuel_type"
#                       class="multi_checkbox multi_auto_fuel_type" data-attr="auto_fuel_type"
#
#                       value="2" type="checkbox">
#                diesel
#              </label>
#            </li>
#            <li class="attr_auto_fuel_type ">
#              <label data-attr="auto_fuel_type">
#                <input id="hybrid_3" name="auto_fuel_type"
#                       class="multi_checkbox multi_auto_fuel_type" data-attr="auto_fuel_type"
#
#                       value="3" type="checkbox">
#                hybrid
#              </label>
#            </li>
#            <li class="attr_auto_fuel_type ">
#              <label data-attr="auto_fuel_type">
#                <input id="electric_4" name="auto_fuel_type"
#                       class="multi_checkbox multi_auto_fuel_type" data-attr="auto_fuel_type"
#
#                       value="4" type="checkbox">
#                electric
#              </label>
#            </li>
#            <li class="attr_auto_fuel_type ">
#              <label data-attr="auto_fuel_type">
#                <input id="other_6" name="auto_fuel_type"
#                       class="multi_checkbox multi_auto_fuel_type" data-attr="auto_fuel_type"
#
#                       value="6" type="checkbox">
#                other
#              </label>
#            </li>
# </ul>      <div id="headerattr_auto_paint" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="auto_paint">
#         <span id="plusminus_auto_paint" class="plusminus">+</span>paint color
#       </div>
# <ul id="ul_auto_paint" class="attr_list hideme">           <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="black_1" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="1" type="checkbox">
#                black
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="blue_2" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="2" type="checkbox">
#                blue
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="brown_20" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="20" type="checkbox">
#                brown
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="green_3" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="3" type="checkbox">
#                green
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="grey_4" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="4" type="checkbox">
#                grey
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="orange_5" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="5" type="checkbox">
#                orange
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="purple_6" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="6" type="checkbox">
#                purple
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="red_7" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="7" type="checkbox">
#                red
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="silver_8" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="8" type="checkbox">
#                silver
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="white_9" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="9" type="checkbox">
#                white
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="yellow_10" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="10" type="checkbox">
#                yellow
#              </label>
#            </li>
#            <li class="attr_auto_paint ">
#              <label data-attr="auto_paint">
#                <input id="custom_11" name="auto_paint"
#                       class="multi_checkbox multi_auto_paint" data-attr="auto_paint"
#
#                       value="11" type="checkbox">
#                custom
#              </label>
#            </li>
# <li class="selectall js-only attr_auto_paint "><label><input type="checkbox" data-attr="auto_paint" class="selectallcb multi_checkbox" > <span class="all select_all_auto_paint">select all</span><span class="none deselect_all_auto_paint">deselect all</span></label></li></ul>      <div id="headerattr_auto_title_status" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="auto_title_status">
#         <span id="plusminus_auto_title_status" class="plusminus">+</span>title status
#       </div>
# <ul id="ul_auto_title_status" class="attr_list hideme">           <li class="attr_auto_title_status ">
#              <label data-attr="auto_title_status">
#                <input id="clean_1" name="auto_title_status"
#                       class="multi_checkbox multi_auto_title_status" data-attr="auto_title_status"
#
#                       value="1" type="checkbox">
#                clean
#              </label>
#            </li>
#            <li class="attr_auto_title_status ">
#              <label data-attr="auto_title_status">
#                <input id="salvage_2" name="auto_title_status"
#                       class="multi_checkbox multi_auto_title_status" data-attr="auto_title_status"
#
#                       value="2" type="checkbox">
#                salvage
#              </label>
#            </li>
#            <li class="attr_auto_title_status ">
#              <label data-attr="auto_title_status">
#                <input id="rebuilt_3" name="auto_title_status"
#                       class="multi_checkbox multi_auto_title_status" data-attr="auto_title_status"
#
#                       value="3" type="checkbox">
#                rebuilt
#              </label>
#            </li>
#            <li class="attr_auto_title_status ">
#              <label data-attr="auto_title_status">
#                <input id="parts_only_4" name="auto_title_status"
#                       class="multi_checkbox multi_auto_title_status" data-attr="auto_title_status"
#
#                       value="4" type="checkbox">
#                parts only
#              </label>
#            </li>
#            <li class="attr_auto_title_status ">
#              <label data-attr="auto_title_status">
#                <input id="lien_5" name="auto_title_status"
#                       class="multi_checkbox multi_auto_title_status" data-attr="auto_title_status"
#
#                       value="5" type="checkbox">
#                lien
#              </label>
#            </li>
#            <li class="attr_auto_title_status ">
#              <label data-attr="auto_title_status">
#                <input id="missing_6" name="auto_title_status"
#                       class="multi_checkbox multi_auto_title_status" data-attr="auto_title_status"
#
#                       value="6" type="checkbox">
#                missing
#              </label>
#            </li>
# </ul>      <div id="headerattr_auto_transmission" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="auto_transmission">
#         <span id="plusminus_auto_transmission" class="plusminus">+</span>transmission
#       </div>
# <ul id="ul_auto_transmission" class="attr_list hideme">           <li class="attr_auto_transmission ">
#              <label data-attr="auto_transmission">
#                <input id="manual_1" name="auto_transmission"
#                       class="multi_checkbox multi_auto_transmission" data-attr="auto_transmission"
#
#                       value="1" type="checkbox">
#                manual
#              </label>
#            </li>
#            <li class="attr_auto_transmission ">
#              <label data-attr="auto_transmission">
#                <input id="automatic_2" name="auto_transmission"
#                       class="multi_checkbox multi_auto_transmission" data-attr="auto_transmission"
#
#                       value="2" type="checkbox">
#                automatic
#              </label>
#            </li>
#            <li class="attr_auto_transmission ">
#              <label data-attr="auto_transmission">
#                <input id="other_3" name="auto_transmission"
#                       class="multi_checkbox multi_auto_transmission" data-attr="auto_transmission"
#
#                       value="3" type="checkbox">
#                other
#              </label>
#            </li>
# </ul></div>
#
#
#
#         <div class="searchgroup resetsearch">
#             <a href="/search/rva" title="clear all search parameters" class="reset linklike">reset</a>
#             <button type="submit" class="searchlink linklike">update search</button>
#         </div>
#
#         <aside class="tsb">
#     <ul>
#         <li><a href="//www.craigslist.org/about/safety">safety tips</a>
#         <li><a href="//www.craigslist.org/about/prohibited">prohibited items</a>
#         <li><a href="//www.craigslist.org/about/recalled_items">product recalls</a>
#         <li><a href="//www.craigslist.org/about/scams">avoiding scams</a>
#     </ul>
# </aside>
#     </div>
# </div>
#
#             <div class="search-legend">
#                 <div class="search-view js-only">
#     <div class="dropdown dropdown-icons dropdown-arrows" role="toolbar" aria-label="view options" aria-expanded="false">
#         <ul class="dropdown-list">
#             <li class="dropdown-item mode sel">
#                 <button title="show results in a list" data-view="list" id="listview">
#                     <span class="view-list icon"></span>list
#                 </button>
#                 <span class="toggle-arrow"></span>
#             </li>
#             <li class="dropdown-item mode">
#                 <button title="show results in a list with thumbnail pictures"  data-view="pic"  id="picview" >
#                     <span class="view-thumb icon"></span>thumb
#                 </button>
#                 <span class="toggle-arrow"></span>
#             </li>
#             <li class="dropdown-item mode">
#                 <button title="show results side-by-side with larger pictures" data-view="grid" id="gridview">
#                     <span class="view-gallery icon"></span>gallery
#                 </button>
#                 <span class="toggle-arrow"></span>
#             </li>
#                 <li class="dropdown-item mode">
#                     <button title="show results on a map"  data-view="map"  id="mapview" >
#                         <span class="view-map icon"></span>map
#                     </button>
#                     <span class="toggle-arrow"></span>
#                 </li>
#         </ul>
#     </div>
# </div>
# <div class="search-sort">
#     <div class="dropdown dropdown-arrows" role="toolbar" aria-label="sort options" aria-expanded="false">
#         <ul class="dropdown-list">
#
#             <li class="dropdown-item mode sel" aria-selected="false">
#                 <a title="show newest matches first" href="/search/rva?sort=date">newest <span class="toggle-arrow"></span></a>
#             </li>
#             <li class="dropdown-item mode " aria-selected="false">
#                 <a title="sort by price, lowest to highest" href="/search/rva?sort=priceasc">price &uarr; <span class="toggle-arrow"></span></a>
#             </li>
#             <li class="dropdown-item mode " aria-selected="false">
#                 <a title="sort by price, highest to lowest" href="/search/rva?sort=pricedsc">price &darr; <span class="toggle-arrow"></span></a>
#             </li>
#
#         </ul>
#     </div>
# </div>
# <div class="paginator buttongroup  firstpage"><span class="resulttotal"><span class="for-map">displaying <span class="displaycountShow">...</span> postings</span></span><span class="buttons"><a href="/search/rva" class="button first" title="first page">&lt;&lt;</a><span class="button first" title="first page">&lt;&lt;</span><a href="/search/rva" class="button prev" title="previous page">&lt; prev</a><span class="button prev" title="previous page">&lt; prev</span><span class="button pagenum"><span class="range"><span class="rangeFrom">1</span> to <span class="rangeTo">100</span></span> of <span class="totalcount">902</span></span><a href="/search/rva?s=100" class="button next" title="next page"> next &gt; </a><span class="button next" title="next page"> next &gt; </span></span></div>
#
#             </div>
#
#             <div class="content" id="sortable-results" >
#                 <section class="favlistsection">
#                     <section class="favlistinfo">
#
#
#                     </section>
#                     <section class="banishlistinfo">
#                     </section>
#                 </section>
#
#
#
#
#
#                 <div class="rows">
#
#
#                     <p class="row" data-pid="5757013901" data-repost-of="5578541680"> <a href="/rvs/5757013901.html" class="i gallery" data-ids="1:00E0E_kIRyjNoIKJy"> <span class="price">$500</span> </a> <span class="txt"> <span class="pl"> <span class="icon icon-star" role="button"> <span class="screen-reader-text">favorite this post</span> </span> <time datetime="2016-08-29 20:31" title="Mon 29 Aug 08:31:01 PM">Aug 29</time> <a href="/rvs/5757013901.html" data-id="5757013901" class="hdrlnk">Fifth wheel hitch</a> </span> <span class="l2"> <span class="price">$500</span> <span class="pnr"> <small> (Mechanisville)</small> <span class="px"> <span class="p"> pic <span class="maptag" data-pid="5757013901">map</span> </span> </span> </span> </span> <span class="js-only banish-unbanish"> <span class="banish" title="hide"> <span class="icon icon-trash" role="button"></span> <span class="screen-reader-text">hide this posting</span> </span> <span class="unbanish" title="restore"> <span class="icon icon-trash red" role="button"></span> <span class="screen-reader-text">restore this posting</span> </span> </span> </span> </p> <p class="row" data-pid="5756888348"> <a href="/rvs/5756888348.html" class="i gallery" data-ids="1:00K0K_2ktxL6rbQr7,1:01717_aOTlXqC21O6,1:00y0y_bzYq2j8Xz3R,1:00a0a_eyUWW0ugsZO,1:00u0u_cFRw8SXhFr,1:01313_g8EJt1W5Omq,1:00B0B_2HCOXWIFRma,1:00T0T_lppcTSkWOYY,1:00c0c_eVbjRemU3vK,1:00808_cgNtDeYTeRT"> <span class="price">$5500</span> </a> <span class="txt"> <span class="pl"> <span class="icon icon-star" role="button"> <span class="screen-reader-text">favorite this post</span> </span> <time datetime="2016-08-29 19:45" title="Mon 29 Aug 07:45:42 PM">Aug 29</time> <a href="/rvs/5756888348.html" data-id="5756888348" class="hdrlnk">Travel Trailer</a> </span> <span class="l2"> <span class="price">$5500</span> <span class="pnr"> <small> (Providence Forge)</small> <span class="px"> <span class="p"> pic <span class="maptag" data-pid="5756888348">map</span> </span> </span> </span> </span> <span class="js-only banish-unbanish"> <span class="banish" title="hide"> <span class="icon icon-trash" role="button"></span> <span class="screen-reader-text">hide this posting</span> </span> <span class="unbanish" title="restore"> <span class="icon icon-trash red" role="button"></span> <span class="screen-reader-text">restore this posting</span> </span> </span> </span> </p> <p class="row" data-pid="5728580352"> <a href="/rvs/5728580352.html" class="i gallery" data-ids="1:00303_hexGg4SWBL7,1:00o0o_bij5p0vIRA,1:00C0C_cuYWEeNSfYA,1:00P0P_1Q1ic0FfkRq,1:01313_YONtioFhJA,1:00j0j_lF7LqgkrXMA"> <span class="price">$30</span> </a> <span class="txt"> <span class="pl"> <span class="icon icon-star" role="button"> <span class="screen-reader-text">favorite this post</span> </span> <time datetime="2016-08-29 19:43" title="Mon 29 Aug 07:43:03 PM">Aug 29</time> <a href="/rvs/5728580352.html" data-id="5728580352" class="hdrlnk">2 waterfront camping spaces on kerr lake</a> </span> <span class="l2"> <span class="price">$30</span> <span class="pnr"> <small> (clarksville va)</small> <span class="px"> <span class="p"> pic <span class="maptag" data-pid="5728580352">map</span> </span> </span> </span> </span> <span class="js-only banish-unbanish"> <span class="banish" title="hide"> <span class="icon icon-trash" role="button"></span> <span class="screen-reader-text">hide this posting</span> </span> <span class="unbanish" title="restore"> <span class="icon icon-trash red" role="button"></span> <span class="screen-reader-text">restore this posting</span> </span> </span> </span> </p> <p class="row" data-pid="5730604577" data-repost-of="5591757107"> <a href="/rvs/5730604577.html" class="i gallery" data-ids="1:00x0x_a0UuQDCe9AK,1:00505_kXAXZxRJXOD,1:00M0M_8PVSRi41jKc,1:00N0N_hjWIGvMiqJG,1:00D0D_1txVRdUlU0y,1:00202_3qvMrMUxi3y,1:00r0r_cY4b2KhQfQL,1:00V0V_kU26h84wWTu"> <span class="price">$95000</span> </a> <span class="txt"> <span class="pl"> <span class="icon icon-star" role="b ...
#
#
#                 </div>
#                 <div id="mapcontainer" data-arealat="37.538300" data-arealon="-77.461502">
#     <div id="noresult-overlay"></div>
#     <div id="noresult-text">
#         <span class="message">No mappable items found</span>
#     </div>
#     <div id="map" class="loading"><div class="closeFS">close fullscreen</div></div>
# </div>
#
#             </div>
#
#             <div class="search-legend bottom">
#                 <div class="search-view">
#                     <span class="buttongroup"><a class="backtotop button" href="#pagecontainer">^ back to top</a></span>
#                 </div>
#                 <div class="search-sort">
#                     <span class="buttongroup"><a class="backtotop button" href="#pagecontainer">^ back to top</a></span>
#                 </div>
#                 <div class="paginator buttongroup  firstpage"><span class="resulttotal"><span class="for-map">displaying <span class="displaycountShow">...</span> postings</span></span><span class="buttons"><a href="/search/rva" class="button first" title="first page">&lt;&lt;</a><span class="button first" title="first page">&lt;&lt;</span><a href="/search/rva" class="button prev" title="previous page">&lt; prev</a><span class="button prev" title="previous page">&lt; prev</span><span class="button pagenum"><span class="range"><span class="rangeFrom">1</span> to <span class="rangeTo">100</span></span> of <span class="totalcount">902</span></span><a href="/search/rva?s=100" class="button next" title="next page"> next &gt; </a><span class="button next" title="next page"> next &gt; </span></span></div>
#             </div>
#
#             <section class="blurbs">
#
#             </section>
#
#             <div id="floater">
#                 <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 <img class="payload" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#             </div>
#             <template id="gallerycarousel">
#                 <div class="slider-info"></div><div class="slider-back arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>
#             </template>
#         </form>
#
#         <aside class="tsb">
#     <ul>
#         <li><a href="//www.craigslist.org/about/safety">safety tips</a>
#         <li><a href="//www.craigslist.org/about/prohibited">prohibited items</a>
#         <li><a href="//www.craigslist.org/about/recalled_items">product recalls</a>
#         <li><a href="//www.craigslist.org/about/scams">avoiding scams</a>
#     </ul>
# </aside>
#
#
#
#         <div class="slidemessage">
#     <span class="fave">
#         <span class="star"></span>
#         favorited
#     </span>
#     <span class="unfave">
#         <span class="star"></span>
#         no longer favorited
#     </span>
#     <span class="hide">
#         <span class="trash"></span>
#         hidden
#     </span>
#     <span class="unhide">
#         <span class="trash"></span>
#         no longer hidden
#     </span>
# </div>
#
#         <footer>
#
#             <span class="rss">
#                 <a class="l" href="https://richmond.craigslist.org/search/rva?format=rss">RSS</a>
#                 <a href="//www.craigslist.org/about/rss">(?)</a><br>
#             </span>
#
#     <ul class="clfooter">
#         <li>&copy; 2016 <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
#         <li><a href="//www.craigslist.org/about/help/">help</a></li>
#         <li><a href="//www.craigslist.org/about/scams">safety</a></li>
#         <li class="desktop"><a href="//www.craigslist.org/about/privacy.policy">privacy</a></li>
#         <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
#         <li class="desktop"><a href="//www.craigslist.org/about/craigslist_is_hiring">cl jobs</a></li>
#         <li><a href="//www.craigslist.org/about/terms.of.use.en">terms</a></li>
#         <li><a href="//www.craigslist.org/about/">about</a></li>
#         <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
#         <li class="fsel mobile linklike" data-mode="regular">desktop</li>
#     </ul>
# </footer>
#     </section>
#
#     <script src="//www.craigslist.org/js/general-concat.min.js?v=a34ded12b261f9807fc3db5e66fb41c6" type="text/javascript" ></script>
#
#     <script type="text/javascript"><!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     --></script>
#     <script type="text/template" id="clustertemplate">
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
# </script>
# <script type="text/template" id="postingtemplate">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <time class="date timeago"  datetime="{isoPostedDate}">{humanPostedDate}</time>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script type="text/template" id="popuptemplate">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=99342ca2e724a94a467ce3d92f15def4" type="text/javascript" ></script>
#
#     <script src="//www.craigslist.org/js/search-concat.min.js?v=56243635ecf4ee65f018516515215750" type="text/javascript" ></script>
#
# </body>
# </html>

# %%
def getRvPricing(city):
    webpath = 'https://%s.craigslist.org/search/rva' % (city)
    response = requests.get(webpath)
    HTML = response.text
    rawline = Selector(text=HTML).xpath("//p[@class='row']/span/span/span[@class='price']/text()").extract()
    outdict = {}
    #outdict['city'] = []
    outdict['price']= []
    for x in rawline:
        #outdict['city'].append(city)
        outdict['price'].append(int(x.replace('$','').encode('utf-8')))
    return outdict

print getRvPricing('richmond')
# Out:
# {'price': [23000, 21000, 119500, 3100, 119500, 5250, 400, 5500, 30, 95000, 29900, 10500, 16500, 29000, 3250, 19950, 49900, 18900, 29900, 17900, 10900, 47900, 59900, 24900, 17900, 13900, 79900, 22900, 26900, 14000, 28500, 10000, 41999, 28995, 17899, 6000, 5900, 14900, 14900, 19900, 19900, 18900, 18900, 21900, 68500, 160, 12900, 6500, 21900, 72900, 45900, 52900, 45900, 26900, 14900, 22900, 12900, 24900, 49900, 64900, 20900, 23900, 13900, 13900, 23900, 23900, 1500, 23900, 24900, 24900, 24900, 69900, 72900, 25900, 79900, 16900, 54900, 16900, 22900, 41900, 54900, 29900, 59900, 21900, 25900, 109995, 37900, 45900, 11900, 84900, 84900, 75900, 1500, 33995, 25000]}

# %%
ascii_cities

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2.1 Create a mapping of cities to cooresponding regional Craigslist URLs
#
# Major US cities on Craigslist typically have their own cooresponding section (ie: SFBay Area, NYC, Boston, Miami, Seattle, etc).  Later, you will use these to query search results for various metropolitian regions listed on Craigslist.  Between the major metropolitan Craigslist sites, the only thing that will differ is the URL's that correspond to them.
#
# The point of the "mapping":  Create a data structure that allows you to iterate with both the name of the city from Wikipedia, with the cooresponding variable that that will allow you to construct each craigslist URL for each region.
#
# > For San Francsico (the Bay Area metropolitan area), the url for the RV search result is:
# > http://sfbay.craigslist.org/search/sss?query=rv
# >
# > The convention is http://[region].craigslist.org/search/sss?query=rf
# > Replacing [region] with the cooresponding city name will allow you to quickly iterate through each regional Craigslist site, and scrape the prices from the search results.  Keep this in mind while you build this "mapping".

# %%
#seattle
#miami
#boston
#oakland
target_cities = ['seattle','miami','richmond','columbus','Chattanooga','Buffalo','boise','phoenix','washingtondc','winchester']
def makemapping(target_cities):
    stored_HTML = []
    allpath ={}
    for city in target_cities:
        print 'http://%s.craiglist.org/search/rva' %(city)
        webpath = 'http://%s.craiglist.org/search/rva' %(city)
        allpath[city] = webpath
    return allpath

url_mapping = makemapping(target_cities)
# Out:
# http://seattle.craiglist.org/search/rva
# http://miami.craiglist.org/search/rva
# http://richmond.craiglist.org/search/rva
# http://columbus.craiglist.org/search/rva
# http://Chattanooga.craiglist.org/search/rva
# http://Buffalo.craiglist.org/search/rva
# http://boise.craiglist.org/search/rva
# http://phoenix.craiglist.org/search/rva
# http://washingtondc.craiglist.org/search/rva
# http://winchester.craiglist.org/search/rva

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Define a function to caculate mean and median price per city.
#
# Now that you've created a list of cities you want to scrape, adapt your solution for grabbing data in one region site, to grab data for all regional sites that you collected, then calculate the mean and median price of RV results from each city.
#
# > Look at the URLs from a few different regions (ie: portland, phoenix, sfbay), and find what they have in common.  Determine the area in the URL string that needs to change the least, and figure out how to replace only that portion of the URL in order to iterate through each city.

# %%
def calc_mean_rv_price(city):
    output = getRvPricing(city)
    #print output['price']
    return np.mean(output['price']), np.median(output['price'])


for city in target_cities:
    print city, ':',calc_mean_rv_price(city)
# Out:
# seattle : (26775.064102564102, 19247.5)
# miami : (16292.597402597403, 6800.0)
# richmond : (32394.978947368421, 23900.0)
# columbus : (27857.141304347828, 14495.0)
# Chattanooga : (44258.797468354431, 29997.0)
# Buffalo : (23783.806122448979, 13947.5)
# boise : (19243.459183673469, 11475.0)
# phoenix : (20473.588888888888, 12995.0)
# washingtondc : (57478.5, 32900.0)
# winchester : (12583.945652173914, 7000.0)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Run your scraping process, and save your results to a CSV file.

# %%
citydatadict = {}
citydatadict['city'] = []
citydatadict['price'] = []


target_cities = ['seattle','miami','richmond','columbus','Chattanooga','Buffalo','boise','phoenix','washingtondc','winchester']
for city in target_cities:
    print city
    output = getRvPricing(city)
    for x in output['price']:
        citydatadict['city'].append(city)
        citydatadict['price'].append(x)
        
city_rv_pricing = pd.DataFrame(citydatadict)
city_rv_pricing.head(5)
city_rv_pricing.to_csv('rv_pricing.csv')
# Out:
# seattle
# miami
# richmond
# columbus
# Chattanooga
# Buffalo
# boise
# phoenix
# washingtondc
# winchester

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Do an analysis of the RV market.
#
# Go head we'll wait.  Anything notable about the data?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
i = 0
colors = ['blue','red','green','yellow','orange','purple','brown','magenta','cyan','black','white','gray']
for x in city_rv_pricing.city.unique():
    city_specific = city_rv_pricing[city_rv_pricing['city']==x]
    rv_mean = city_specific['price'].mean()
    rv_std = city_specific['price'].std()
    print rv_mean, rv_std
    trimmed_set = city_rv_pricing[(city_rv_pricing['price'] < rv_mean+rv_std) & (city_rv_pricing['price'] > rv_mean-rv_std) ] 
    plt.hist(trimmed_set['price'], alpha=0.2, color = colors[i])
    i +=1
    plt.legend()
# Out:
# 27094.2692308 43111.1519431
# 15934.6052632 21066.7315111
# 32394.9789474 26888.6081791
# 27282.0326087 37141.2385348
# 44258.7974684 49657.17859
# 23783.8061224 42281.3545408
# 19243.4591837 23562.0797938
# 20473.5888889 24629.2180098
# 57478.5 61638.9813749
# 12583.9456522 16132.531919

# %%
import seaborn as sns
total_trim = pd.DataFrame()
for x in city_rv_pricing.city.unique():
    city_specific = city_rv_pricing[city_rv_pricing['city']==x]
    rv_mean = city_specific['price'].mean()
    rv_std = city_specific['price'].std()
    print rv_mean, rv_std
    trimmed_set = city_rv_pricing[(city_rv_pricing['price'] < rv_mean+rv_std) & (city_rv_pricing['price'] > rv_mean-rv_std) ] 
    total_trim = pd.concat([total_trim, trimmed_set])

fig = plt.figure(figsize = [11,6])
sns.boxplot(total_trim['city'],total_trim['price'])
# Out:
# 27094.2692308 43111.1519431
# 15934.6052632 21066.7315111
# 32394.9789474 26888.6081791
# 27282.0326087 37141.2385348
# 44258.7974684 49657.17859
# 23783.8061224 42281.3545408
# 19243.4591837 23562.0797938
# 20473.5888889 24629.2180098
# 57478.5 61638.9813749
# 12583.9456522 16132.531919

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.1 Does it makes sense to buy RVs in one region and sell them in another?
#
# Assuming the cost of shipping or driving from one regional market to another.

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.2 Can you pull out the "make" from the markup and include that in your analyis?
# How reliable is this data and does it make sense?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.3 Are there any other variables you could pull out of the markup to help describe your dataset?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. Move your project into scrapy (if you haven't used Scrapy yet)
#
# >Start a project by using the command `scrapy startproject [projectname]`
# > - Update your settings.py (review our past example)
# > - Update your items.py
# > - Create a spiders file in your `[project_name]/[project_name]/spiders` directory
#
# You can update your spider class with the complete list of craigslist "start urls" to effectively scrape all of the regions.  Start with one to test.
#
# Updating your parse method with the method you chose should require minimal changes.  It will require you to update your parse method to use the response parameter, and an item model (defined in items.py).

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7.  Chose another area of Craigslist to scrape.
#
# **Choose an area having more than a single page of results, then scrape multiple regions, multiple pages of search results and or details pages.**
#
# This is the true exercise of being able to understand how to succesffuly plan, develop, and employ a broader scraping strategy.  Even though this seems like a challenging task, a few tweeks of your current code can make this very managable if you've pieced together all the touch points.  If you are still confused as to some of the milestones within this process, this is an excellent opportunity to round out your understanding, or help you build a list of questions to fill in your gaps.
#
# _Use Scrapy!  Provide your code in this project directory when you submit this project._
